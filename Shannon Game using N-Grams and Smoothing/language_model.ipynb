# %%
import pickle
import matplotlib.pyplot as plt
from collections import Counter
import math

# %%
# Load the data
with open('./Data/test_pride_prejudice.pkl', 'rb') as f:
    test_pride_prejudice = pickle.load(f)

with open('./Data/train_pride_prejudice.pkl', 'rb') as f:
    train_pride_prejudice = pickle.load(f)

with open('./Data/vocab_pride_prejudice.pkl', 'rb') as f:
    vocab_pride_prejudice = pickle.load(f)

with open('./Data/vocab_ulysses.pkl', 'rb') as f:
    vocab_ulysses = pickle.load(f)

with open('./Data/test_ulysses.pkl', 'rb') as f:
    test_ulysses = pickle.load(f)

with open('./Data/train_ulysses.pkl', 'rb') as f:
    train_ulysses = pickle.load(f)

# %%
# DECLARING SOME GLOBAL VARIABLES WHICH WILL BE USED IN THE CODE

# dictionary with key having the N of N gram
all_n_grams = {1: [], 2: [], 3: [], 4: [], 5: []}
# the number of unique words before which the sequence occurs (the numerator in (1- lambda) expression)
unique_n_grams = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}
# dictionary with key having the N of N gram,  which itself is a dictionary of the count of that N-gram (the other denominator in the (1-lambda) expression)
n_gram_counts = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}
probabilities = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}
all_tokens_vocab = []
all_tokens_in_corpus = []
witten_bell_probabilities = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}

# therefore
# (1-lambda) = unique_n_grams / (n_gram_counts + unique_n_grams)

# %%
def convert_to_sentence_tokens(corpus, n):
    """
    This function converts the corpus into a list of sentences, where each sentence is a list of tokens
    :param corpus: the corpus
    :return: list of sentences, where each sentence is a list of tokens
    """
    sentences_tokens = []
    intial_tokens = "<START> "*(n-1)
    intial_tokens = intial_tokens.split()
    sentences_tokens = sentences_tokens + \
        [intial_tokens+s.split()+["<END>"] for s in corpus]
        
    return sentences_tokens

# %%
def find_probablity(n):
    """
    This function finds the probability of each n-gram in the corpus
    """
    if (n == 1):
        # for unigrams the probability will be the count of the word divided by the total number of words in the corpus
        for n_gram in n_gram_counts[n]:
            probability = n_gram_counts[n][n_gram]/len(all_tokens_in_corpus)
            probabilities[n].update({n_gram: probability})
            # print("Added probability for n_gram: ", n_gram, " with probability: ", probability)
    else:
        # for all other n-gram the probability will be the count of the n-gram divided by the count of the n-1 gram
        for n_gram in n_gram_counts[n]:
            history = n_gram[:(n-1)]
            probability = n_gram_counts[n][n_gram]/n_gram_counts[n-1][history]
            probabilities[n].update({n_gram: probability})

# %%
def find_ngrams(n, input_list):  # go inside the list of sentences
    """
    This function finds all the n-grams in the corpus
    """
    for i in range(len(input_list)):  # for each sentence find all the n-grams
        for j in range(len(input_list[i])-n+1):
            ngram = tuple(input_list[i][j:j+n])
            all_n_grams[n].append(ngram)

# %%
def common_data(n, train_data, train_data_vocab):

    sentences_tokens = convert_to_sentence_tokens(train_data, n)

    all_tokens_vocab.extend(train_data_vocab)
    all_tokens_in_corpus.extend(
        [token for s in sentences_tokens for token in s])

    for i in range(1, 5):
        find_ngrams(i, sentences_tokens)
        n_gram_counts[i] = dict(Counter(all_n_grams[i]))
        unique_n_grams[i-1] = dict(Counter([i[:-1]
                                   for i in n_gram_counts[i].keys()]))
        find_probablity(i)

# %%
def empty_dict():
    for i in range(1, 6):
        all_n_grams[i] = []
        n_gram_counts[i] = {}
        unique_n_grams[i] = {}
        probabilities[i] = {}
        witten_bell_probabilities[i] = {}

# %%
# common_data(4, train_pride_prejudice, vocab_pride_prejudice)

# %%
# all_n_grams[4]
# n_gram_counts[3]
# unique_n_grams[2]
# probabilities[3]

# %%
# fig, ax= plt.subplots()
# for i in range(1, 6):
#     ax.scatter(i, len(n_gram_counts[i]))
#     ax.stem(i, len(unique_n_grams[i-1]))
# plt.show()

# %% [markdown]
# ---
#
# ## Witten Bell Smoothing
#
# It is the nth-order smoothed model is defiined recursively as a linear interpolation between the nth-order maximum likelihood model and the (n - 1)th-order smoothed model as in equation
# <br><br>
# <img src="./images/witten1.png" alt="Witten Bell Formula">
#
# To compute the parameters lambda for Witten-Bell smooothing, we will need to use the number of unique words that follow the history w (i-1),(i-n+1) . We will write this value as N1+ (w (i-1), (i-n+1)), formally defined as
# <br><br>
# <img src="./images/witten2.png" alt="Witten Bell Formula">
#
#
# The notation N1+ is meant to evoke the number of words that have one or more counts, and the black dot is meant to evoke a free  variable that is summed over. We can then assign the parameters lambda (i-1), (i-n+1) for Witten-Bell smoothing such that
# <br><br>
# <img src="./images/witten3.png" alt="Witten Bell Formula">
#
# Substituting, we can rewrite the equaltion as
# <br><br>
# <img src="./images/witten4.png" alt="Witten Bell Formula">
#
#
# ---

# %%
empty_dict()
common_data(4, train_pride_prejudice, vocab_pride_prejudice)

# %%
def find_lambda(n, history):
    unique_n_grams[n-1].setdefault(history, 0)
    n_gram_counts[n-1].setdefault(history, 0)
    # if the history is not present in the corpus then we will assign zero probability to the current n-gram and shift all the mass to the next (n-1)-gram
    if ((unique_n_grams[n-1][history]+n_gram_counts[n-1][history]) == 0):
        return 0
    
    lamda = 1-(unique_n_grams[n-1][history]/(n_gram_counts[n-1]
               [history]+unique_n_grams[n-1][history]))
    return lamda

# %%
def witten_bell_for_one(n,  tuple_n):
    history = tuple_n[:(n-1)]
    if (n == 1):
        n_gram_counts[n].setdefault(tuple_n, 1)
        witten_probability= n_gram_counts[n][tuple_n]/len(unique_n_grams[n].keys())
        # witten_probability = n_gram_counts[n][tuple_n]/len(all_tokens_in_corpus) + (1 / (len(all_tokens_in_corpus)+len(all_tokens_vocab)))
        witten_bell_probabilities[n].update({tuple_n: witten_probability})
        return witten_probability

    lamda = find_lambda(n, history)
    probabilities[n].setdefault(tuple_n, (1/len(probabilities[n].keys())))
    witten_probability = probabilities[n][tuple_n] * \
        lamda + (1-lamda)*witten_bell_for_one(n-1, tuple_n[1:])
    witten_bell_probabilities[n].update({tuple_n: witten_probability})

    return witten_probability

# %%
def witten_bell(n):
    for tuplee in n_gram_counts[n].keys():
        witten_bell_for_one(n,tuplee)

# %%
witten_bell(4)
# probabilities[4]
witten_bell_probabilities[4]
# Out:
# {('<START>', '<START>', '<START>', 'pride'): 0.0006575282474925164,
#  ('<START>', '<START>', 'pride', '&'): 0.41670046154046514,
#  ('<START>', 'pride', '&', 'prejudice'): 0.9444739889857949,
#  ('pride', '&', 'prejudice', '<END>'): 0.9751453314454371,
#  ('<START>', '<START>', '<START>', 'it'): 0.03352607373542354,
#  ('<START>', '<START>', 'it', 'is'): 0.30942756616136785,
#  ('<START>', 'it', 'is', 'a'): 0.15004926935921323,
#  ('it', 'is', 'a', 'truth'): 0.035033102894129454,
#  ('is', 'a', 'truth', 'universally'): 0.7576120167855969,
#  ('a', 'truth', 'universally', 'acknowledged'): 0.7919857477132525,
#  ('truth', 'universally', 'acknowledged', ','): 0.9361531098129694,
#  ('universally', 'acknowledged', ',', 'that'): 0.6036332661429482,
#  ('acknowledged', ',', 'that', 'a'): 0.26068606440902653,
#  (',', 'that', 'a', 'single'): 0.12348958929611215,
#  ('that', 'a', 'single', 'man'): 0.6144499512399959,
#  ('a', 'single', 'man', 'in'): 0.3992974405896449,
#  ('single', 'man', 'in', 'possession'): 0.5457715328882187,
#  ('man', 'in', 'possession', 'of'): 0.9524078346669285,
#  ('in', 'possession', 'of', 'a'): 0.4864957109519294,
#  ('possession', 'of', 'a', 'good'): 0.25708879433767257,
#  ('of', 'a', 'good', 'fortune'): 0.5128496269374515,
#  ('a', 'good', 'fortune', ','): 0.8235400344879089,
#  ('good', 'fortune', ',', 'must'): 0.27283008171022477,
#  ('fortune', ',', 'must', 'be'): 0.6636721875028809,
#  (',', 'must', 'be', 'in'): 0.14316213209947348,
#  ('must', 'be', 'in', 'want'): 0.10906301573282191,
#  ('be', 'in', 'want', 'of'): 0.8643524830306898,
#  ('in', 'want', 'of', 'a'): 0.5354364880904099,
#  ('want', 'of', 'a', 'wife'): 0.5034717548575429,
#  ('of', 'a', 'wife', '<END>'): 0.6699098752455672,
#  ('<START>', '<START>', '<START>', 'however'): 0.0011509758317777084,
#  ('<START>', '<START>', 'however', 'little'): 0.2728521390112101,
#  ('<START>', 'however', 'little', 'known'): 0.3349605351041216,
#  ('however', 'little', 'known', 'the'): 0.8143225770650093,
#  ('little', 'known', 'the', 'feelings'): 0.5845178128120152,
#  ('known', 'the', 'feelings', 'or'): 0.5421067635724287,
#  ('the', 'feelings', 'or', 'views'): 0.7506549185682512,
#  ('feelings', 'or', 'views', 'of'): 0.8553920265191803,
#  ('or', 'views', 'of', 'such'): 0.5667267651501603,
#  ('views', 'of', 'such', 'a'): 0.7013328180190594,
#  ('of', 'such', 'a', 'man'): 0.05306844853057032,
#  ('such', 'a', 'man', 'may'): 0.21176551135379112,
#  ('a', 'man', 'may', 'be'): 0.8009128177252675,
#  ('man', 'may', 'be', 'on'): 0.5149575245815462,
#  ('may', 'be', 'on', 'his'): 0.5749052763882313,
#  ('be', 'on', 'his', 'first'): 0.5235089759412206,
#  ('on', 'his', 'first', 'entering'): 0.21798933357644268,
#  ('his', 'first', 'entering', 'a'): 0.7938470538183365,
#  ('first', 'entering', 'a', 'neighbourhood'): 0.7503842587762116,
#  ('entering', 'a', 'neighbourhood', ','): 0.9303778092067818,
#  ('a', 'neighbourhood', ',', 'this'): 0.5245421470095935,
#  ('neighbourhood', ',', 'this', 'truth'): 0.5171717796831148,
#  (',', 'this', 'truth', 'is'): 0.7666405600355823,
#  ('this', 'truth', 'is', 'so'): 0.7577400639457854,
#  ('truth', 'is', 'so', 'well'): 0.5321848516538907,
#  ('is', 'so', 'well', 'fixed'): 0.5138477641269601,
#  ('so', 'well', 'fixed', 'in'): 0.7914890828699062,
#  ('well', 'fixed', 'in', 'the'): 0.6944559946100874,
#  ('fixed', 'in', 'the', 'minds'): 0.501024290121883,
#  ('in', 'the', 'minds', 'of'): 0.8406361108578722,
#  ('the', 'minds', 'of', 'the'): 0.8039414429271672,
#  ('minds', 'of', 'the', 'surrounding'): 0.5008289192078379,
#  ('of', 'the', 'surrounding', 'families'): 0.8125797702616464,
#  ('the', 'surrounding', 'families', ','): 0.9482490427568603,
#  ('surrounding', 'families', ',', 'that'): 0.763996592757243,
#  ('families', ',', 'that', 'he'): 0.5574524852870468,
#  (',', 'that', 'he', 'is'): 0.07245737068347151,
#  ('that', 'he', 'is', 'considered'): 0.06075345593905351,
#  ('he', 'is', 'considered', 'as'): 0.7877820966525497,
#  ('is', 'considered', 'as', 'the'): 0.6153315583966465,
#  ('considered', 'as', 'the', 'rightful'): 0.507744903712042,
#  ('as', 'the', 'rightful', 'property'): 0.8751794830887045,
#  ('the', 'rightful', 'property', 'of'): 0.8250122001576636,
#  ('rightful', 'property', 'of', 'some'): 0.7524188529989221,
#  ('property', 'of', 'some', 'one'): 0.5361850996278484,
#  ('of', 'some', 'one', 'or'): 0.380947759341984,
#  ('some', 'one', 'or', 'other'): 0.5938708747603745,
#  ('one', 'or', 'other', 'of'): 0.5583830502309727,
#  ('or', 'other', 'of', 'their'): 0.7577114205116828,
#  ('other', 'of', 'their', 'daughters'): 0.5045335027406954,
#  ('of', 'their', 'daughters', '<END>'): 0.8642719925518616,
#  ('<START>', '<START>', '<START>', 'my'): 0.015776855136489555,
#  ('<START>', '<START>', 'my', 'dear'): 0.3365493567199811,
#  ('<START>', 'my', 'dear', 'mr'): 0.11751045971559129,
#  ('my', 'dear', 'mr', '<END>'): 0.999997626928637,
#  ('<START>', '<START>', '<START>', 'bennet'): 0.029081917035009213,
#  ('<START>', '<START>', 'bennet', ','): 0.3186309710613775,
#  ('<START>', 'bennet', ',', 'said'): 0.03961582520263529,
#  ('bennet', ',', 'said', 'his'): 0.14856545440841032,
#  (',', 'said', 'his', 'lady'): 0.3771458250838471,
#  ('said', 'his', 'lady', 'to'): 0.6507471668408171,
#  ('his', 'lady', 'to', 'him'): 0.6316121088120147,
#  ('lady', 'to', 'him', 'one'): 0.5091948451817544,
#  ('to', 'him', 'one', 'day'): 0.6319684863149684,
#  ('him', 'one', 'day', ','): 0.7868079656616342,
#  ('one', 'day', ',', 'have'): 0.11185358573302669,
#  ('day', ',', 'have', 'you'): 0.5691359577154789,
#  (',', 'have', 'you', 'heard'): 0.45240392236917104,
#  ('have', 'you', 'heard', 'that'): 0.22212161918281764,
#  ('you', 'heard', 'that', 'netherfield'): 0.5840372986051896,
#  ('heard', 'that', 'netherfield', 'park'): 0.6279086756457193,
#  ('that', 'netherfield', 'park', 'is'): 0.7675470402815648,
#  ('netherfield', 'park', 'is', 'let'): 0.7509008775538631,
#  ('park', 'is', 'let', 'at'): 0.7579352188588432,
#  ('is', 'let', 'at', 'last'): 0.7607046137503737,
#  ('let', 'at', 'last', '<END>'): 0.6318500814904661,
#  ('<START>', '<START>', 'bennet', 'replied'): 0.005722912445374892,
#  ('<START>', 'bennet', 'replied', 'that'): 0.7682421993080979,
#  ('bennet', 'replied', 'that', 'he'): 0.7248113107818301,
#  ('replied', 'that', 'he', 'had'): 0.34833064854225243,
#  ('that', 'he', 'had', 'not'): 0.05998551101709483,
#  ('he', 'had', 'not', '<END>'): 0.1382754032800031,
#  ('<START>', '<START>', '<START>', 'but'): 0.04387325809554891,
#  ('<START>', '<START>', 'but', 'it'): 0.05424010786834172,
#  ('<START>', 'but', 'it', 'is'): 0.4463951739611145,
#  ('but', 'it', 'is', ','): 0.10231467484200749,
#  ('it', 'is', ',', 'returned'): 0.0716744944020628,
#  ('is', ',', 'returned', 'she'): 0.6091054588182858,
#  (',', 'returned', 'she', ';'): 0.7591562718836726,
#  ('returned', 'she', ';', 'for'): 0.5970368208757092,
#  ('she', ';', 'for', 'mrs'): 0.5181414649555101,
#  (';', 'for', 'mrs', '<END>'): 0.9999874029461817,
#  ('<START>', '<START>', '<START>', 'long'): 0.0014793813292633888,
#  ('<START>', '<START>', 'long', 'has'): 0.17980095525578377,
#  ('<START>', 'long', 'has', 'just'): 0.3350878423910427,
#  ('long', 'has', 'just', 'been'): 0.7663268400866889,
#  ('has', 'just', 'been', 'here'): 0.5651019977718408,
#  ('just', 'been', 'here', ','): 0.6916909627071419,
#  ('been', 'here', ',', 'and'): 0.597070261468611,
#  ('here', ',', 'and', 'she'): 0.18836686063324376,
#  (',', 'and', 'she', 'told'): 0.01917675582178664,
#  ('and', 'she', 'told', 'me'): 0.8051142534063301,
#  ('she', 'told', 'me', 'all'): 0.2103444468621491,
#  ('told', 'me', 'all', 'about'): 0.6264837838453825,
#  ('me', 'all', 'about', 'it'): 0.7920911824578126,
#  ('all', 'about', 'it', '<END>'): 0.6310572483705943,
#  ('<START>', '<START>', 'bennet', 'made'): 0.01124926696329362,
#  ('<START>', 'bennet', 'made', 'no'): 0.9055314122557083,
#  ('bennet', 'made', 'no', 'answer'): 0.8768715372257756,
#  ('made', 'no', 'answer', '<END>'): 0.5311925727977499,
#  ('<START>', '<START>', '<START>', 'do'): 0.00394541365602613,
#  ('<START>', '<START>', 'do', 'not'): 0.45594057506482105,
#  ('<START>', 'do', 'not', 'you'): 0.06802509687632323,
#  ('do', 'not', 'you', 'want'): 0.14423486215743384,
#  ('not', 'you', 'want', 'to'): 0.922652760051053,
#  ('you', 'want', 'to', 'know'): 0.22011989272393634,
#  ('want', 'to', 'know', 'who'): 0.26087406475331115,
#  ('to', 'know', 'who', 'has'): 0.5926273757397578,
#  ('know', 'who', 'has', 'taken'): 0.5296992512334954,
#  ('who', 'has', 'taken', 'it'): 0.6532386726228462,
#  ('has', 'taken', 'it', '<END>'): 0.805459372090347,
#  ('<START>', '<START>', '<START>', 'cried'): 0.00345074521638578,
#  ('<START>', '<START>', 'cried', 'his'): 0.04977661359095329,
#  ('<START>', 'cried', 'his', 'wife'): 0.7527931196358157,
#  ('cried', 'his', 'wife', 'impatiently'): 0.18347802292246626,
#  ('his', 'wife', 'impatiently', '<END>'): 0.9220929437505698,
#  ('<START>', '<START>', '<START>', 'you'): 0.027610776479393143,
#  ('<START>', '<START>', 'you', 'want'): 0.005756321078198401,
#  ('<START>', 'you', 'want', 'to'): 0.922652760051053,
#  ('you', 'want', 'to', 'tell'): 0.1927277595954363,
#  ('want', 'to', 'tell', 'me'): 0.5784991439107585,
#  ('to', 'tell', 'me', ','): 0.41390655466887505,
#  ('tell', 'me', ',', 'and'): 0.22914285177205565,
#  ('me', ',', 'and', 'i'): 0.17657162786842598,
#  (',', 'and', 'i', 'have'): 0.08211010886361077,
#  ('and', 'i', 'have', 'no'): 0.14639694605903525,
#  ('i', 'have', 'no', 'objection'): 0.08731102747520747,
#  ('have', 'no', 'objection', 'to'): 0.44899227022711385,
#  ('no', 'objection', 'to', 'hearing'): 0.30018655074882467,
#  ('objection', 'to', 'hearing', 'it'): 0.7991770796879182,
#  ('to', 'hearing', 'it', '<END>'): 0.617959372090347,
#  ('<START>', '<START>', '<START>', 'this'): 0.00903944536692532,
#  ('<START>', '<START>', 'this', 'was'): 0.2399037381189174,
#  ('<START>', 'this', 'was', 'invitation'): 0.052536005414464265,
#  ('this', 'was', 'invitation', 'enough'): 0.756784017584911,
#  ('was', 'invitation', 'enough', '<END>'): 0.807861676954442,
#  ('<START>', '<START>', '<START>', 'why'): 0.002957640997669226,
#  ('<START>', '<START>', 'why', ','): 0.41047028541959985,
#  ('<START>', 'why', ',', 'my'): 0.10705636686734787,
#  ('why', ',', 'my', 'dear'): 0.7754144744576692,
#  (',', 'my', 'dear', ','): 0.2995806203420627,
#  ('my', 'dear', ',', 'you'): 0.1487077721711899,
#  ('dear', ',', 'you', 'must'): 0.3558516228092774,
#  (',', 'you', 'must', 'know'): 0.10210557490488992,
#  ('you', 'must', 'know', ','): 0.3146902858943345,
#  ('must', 'know', ',', 'mrs'): 0.2642378200796056,
#  ('know', ',', 'mrs', '<END>'): 0.9999924417677091,
#  ('<START>', '<START>', 'long', 'says'): 0.08817572673839778,
#  ('<START>', 'long', 'says', 'that'): 0.8240223711267106,
#  ('long', 'says', 'that', 'netherfield'): 0.5632039652718562,
#  ('says', 'that', 'netherfield', 'is'): 0.6397096362476069,
#  ('that', 'netherfield', 'is', 'taken'): 0.6255012163952588,
#  ('netherfield', 'is', 'taken', 'by'): 0.7651112621736356,
#  ('is', 'taken', 'by', 'a'): 0.7760916136458879,
#  ('taken', 'by', 'a', 'young'): 0.5321470265858564,
#  ('by', 'a', 'young', 'man'): 0.8884726130159283,
#  ('a', 'young', 'man', 'of'): 0.29936873573266987,
#  ('young', 'man', 'of', 'large'): 0.12063839244708927,
#  ('man', 'of', 'large', 'fortune'): 0.9025825152181247,
#  ('of', 'large', 'fortune', 'from'): 0.329584050215016,
#  ('large', 'fortune', 'from', 'the'): 0.823150435802191,
#  ('fortune', 'from', 'the', 'north'): 0.503601353546454,
#  ('from', 'the', 'north', 'of'): 0.7009452776005105,
#  ('the', 'north', 'of', 'england'): 0.8889899149323524,
#  ('north', 'of', 'england', ';'): 0.8418917960717578,
#  ('of', 'england', ';', 'that'): 0.38285868905709086,
#  ('england', ';', 'that', 'he'): 0.5946323904639623,
#  (';', 'that', 'he', 'came'): 0.13124212750826028,
#  ('that', 'he', 'came', 'down'): 0.27556193717648725,
#  ('he', 'came', 'down', 'on'): 0.6388188381098799,
#  ('came', 'down', 'on', 'monday'): 0.5840537853133513,
#  ('down', 'on', 'monday', 'in'): 0.6717888843766316,
#  ('on', 'monday', 'in', 'a'): 0.7768364392778762,
#  ('monday', 'in', 'a', 'chaise'): 0.5028886021538514,
#  ('in', 'a', 'chaise', 'and'): 0.7711960980946303,
#  ('a', 'chaise', 'and', 'four'): 0.8890344451898045,
#  ('chaise', 'and', 'four', 'to'): 0.44620492980216975,
#  ('and', 'four', 'to', 'see'): 0.7543379374517494,
#  ('four', 'to', 'see', 'the'): 0.5522952548024673,
#  ('to', 'see', 'the', 'place'): 0.5563952612267317,
#  ('see', 'the', 'place', ','): 0.583850916378374,
#  ('the', 'place', ',', 'and'): 0.37857464117529654,
#  ('place', ',', 'and', 'was'): 0.1430512240539245,
#  (',', 'and', 'was', 'so'): 0.07569703789890621,
#  ('and', 'was', 'so', 'much'): 0.33712535183637465,
#  ('was', 'so', 'much', 'delighted'): 0.13130258511756876,
#  ('so', 'much', 'delighted', 'with'): 0.8303698681131675,
#  ('much', 'delighted', 'with', 'it'): 0.5861761241874833,
#  ('delighted', 'with', 'it', 'that'): 0.2888564344523837,
#  ('with', 'it', 'that', 'he'): 0.6873427589848585,
#  ('it', 'that', 'he', 'agreed'): 0.2526001056022154,
#  ('that', 'he', 'agreed', 'with'): 0.7773038648691768,
#  ('he', 'agreed', 'with', 'mr'): 0.7569254619486174,
#  ('agreed', 'with', 'mr', '<END>'): 0.9999961239834405,
#  ('<START>', '<START>', '<START>', 'morris'): 0.00016430194324044685,
#  ('<START>', '<START>', 'morris', 'immediately'): 0.8760569559668155,
#  ('<START>', 'morris', 'immediately', ';'): 0.7843851567949423,
#  ('morris', 'immediately', ';', 'that'): 0.5625410569396363,
#  ('immediately', ';', 'that', 'he'): 0.5946323904639623,
#  (';', 'that', 'he', 'is'): 0.15473868760415463,
#  ('that', 'he', 'is', 'to'): 0.1002337952408845,
#  ('he', 'is', 'to', 'take'): 0.18223012427259253,
#  ('is', 'to', 'take', 'possession'): 0.5185451807255576,
#  ('to', 'take', 'possession', 'before'): 0.646562515340435,
#  ('take', 'possession', 'before', 'michaelmas'): 0.7510665082880632,
#  ('possession', 'before', 'michaelmas', ','): 0.9794990427568603,
#  ('before', 'michaelmas', ',', 'and'): 0.8009498663478408,
#  ('michaelmas', ',', 'and', 'some'): 0.5017156202172597,
#  (',', 'and', 'some', 'of'): 0.2956931460075395,
#  ('and', 'some', 'of', 'his'): 0.5689449928244039,
#  ('some', 'of', 'his', 'servants'): 0.16837383424049857,
#  ('of', 'his', 'servants', 'are'): 0.7671288507280849,
#  ('his', 'servants', 'are', 'to'): 0.8018841942103294,
#  ('servants', 'are', 'to', 'be'): 0.623107525233694,
#  ('are', 'to', 'be', 'in'): 0.1559268111317199,
#  ('to', 'be', 'in', 'the'): 0.15248383617221645,
#  ('be', 'in', 'the', 'house'): 0.17284062227064054,
#  ('in', 'the', 'house', 'by'): 0.13568433810637542,
#  ('the', 'house', 'by', 'the'): 0.8219308228813279,
#  ('house', 'by', 'the', 'end'): 0.5060770890950527,
#  ('by', 'the', 'end', 'of'): 0.9834302848821037,
#  ('the', 'end', 'of', 'next'): 0.08513998150221325,
#  ('end', 'of', 'next', 'week'): 0.6335722350400078,
#  ('of', 'next', 'week', '<END>'): 0.7774858138291451,
#  ('<START>', '<START>', '<START>', 'what'): 0.009696424229508015,
#  ('<START>', '<START>', 'what', 'is'): 0.12996450758263964,
#  ('<START>', 'what', 'is', 'his'): 0.08439347181108435,
#  ('what', 'is', 'his', 'name'): 0.5636374199925972,
#  ('is', 'his', 'name', '<END>'): 0.7149755371197617,
#  ('<START>', '<START>', '<START>', 'is'): 0.0034559033302613233,
#  ('<START>', '<START>', 'is', 'he'): 0.04767585138430761,
#  ('<START>', 'is', 'he', 'married'): 0.563028688941434,
#  ('is', 'he', 'married', 'or'): 0.7610821133642571,
#  ('he', 'married', 'or', 'single'): 0.8341084841992996,
#  ('married', 'or', 'single', '<END>'): 0.49947389613152215,
#  ('<START>', '<START>', '<START>', 'single'): 0.00016438587704611398,
#  ('<START>', '<START>', 'single', ','): 0.9169515604582612,
#  ('<START>', 'single', ',', 'my'): 0.6293777954387765,
#  ('single', ',', 'my', 'dear'): 0.7754144744576692,
#  ('my', 'dear', ',', 'to'): 0.08061748994537374,
#  ('dear', ',', 'to', 'be'): 0.3111288605820878,
#  (',', 'to', 'be', 'sure'): 0.09823688606012924,
#  ('to', 'be', 'sure', '<END>'): 0.15371991092761703,
#  ('<START>', '<START>', '<START>', 'a'): 0.006913569270441656,
#  ('<START>', '<START>', 'a', 'single'): 0.01992740114425972,
#  ('<START>', 'a', 'single', 'man'): 0.6144499512399959,
#  ('a', 'single', 'man', 'of'): 0.4227905750643445,
#  ('single', 'man', 'of', 'large'): 0.5373050591137559,
#  ('of', 'large', 'fortune', ';'): 0.34186818558296783,
#  ('large', 'fortune', ';', 'four'): 0.6252529424119295,
#  ('fortune', ';', 'four', 'or'): 0.768243458838545,
#  (';', 'four', 'or', 'five'): 0.834265402426023,
#  ('four', 'or', 'five', 'thousand'): 0.8964905024147739,
#  ('or', 'five', 'thousand', 'a'): 0.8328659734474517,
#  ('five', 'thousand', 'a', 'year'): 0.5283193303440998,
#  ('thousand', 'a', 'year', '<END>'): 0.3730125605602803,
#  ('<START>', '<START>', 'what', 'a'): 0.14608114522851642,
#  ('<START>', 'what', 'a', 'fine'): 0.07272545794356279,
#  ('what', 'a', 'fine', 'thing'): 0.5491586896405021,
#  ('a', 'fine', 'thing', 'for'): 0.7669238481498158,
#  ('fine', 'thing', 'for', 'our'): 0.5513796846279296,
#  ('thing', 'for', 'our', 'girls'): 0.5650764557763563,
#  ('for', 'our', 'girls', '<END>'): 0.8364042327328064,
#  ('<START>', '<START>', '<START>', 'how'): 0.00953060384741959,
#  ('<START>', '<START>', 'how', 'so'): 0.01906946881869106,
#  ('<START>', 'how', 'so', '<END>'): 0.8318868882748575,
#  ('<START>', '<START>', 'how', 'can'): 0.09465572389067378,
#  ('<START>', 'how', 'can', 'it'): 0.14102076347855985,
#  ('how', 'can', 'it', 'affect'): 0.5556758299303833,
#  ('can', 'it', 'affect', 'them'): 0.799204956392257,
#  ('it', 'affect', 'them', '<END>'): 0.8331161434771874,
#  ('<START>', '<START>', 'you', 'must'): 0.0977135926582248,
#  ('<START>', 'you', 'must', 'know'): 0.06617577234915666,
#  ('you', 'must', 'know', 'that'): 0.3133581938756988,
#  ('must', 'know', 'that', 'i'): 0.2247247045283997,
#  ('know', 'that', 'i', 'am'): 0.46309661866085516,
#  ('that', 'i', 'am', 'thinking'): 0.03673287265366816,
#  ('i', 'am', 'thinking', 'of'): 0.9282912619064502,
#  ('am', 'thinking', 'of', 'his'): 0.3241314167260001,
#  ('thinking', 'of', 'his', 'marrying'): 0.5035234313098425,
#  ('of', 'his', 'marrying', 'one'): 0.358652270649718,
#  ('his', 'marrying', 'one', 'of'): 0.8276901412819968,
#  ('marrying', 'one', 'of', 'them'): 0.5445860911193282,
#  ('one', 'of', 'them', '<END>'): 0.40615428607373183,
#  ('<START>', '<START>', 'is', 'that'): 0.04895923898436462,
#  ('<START>', 'is', 'that', 'his'): 0.5531896072725087,
#  ('is', 'that', 'his', 'design'): 0.5091044002785816,
#  ('that', 'his', 'design', 'in'): 0.6561742182514358,
#  ('his', 'design', 'in', 'settling'): 0.7501452859071003,
#  ('design', 'in', 'settling', 'here'): 0.7928233354605403,
#  ('in', 'settling', 'here', '<END>'): 0.8628453583092459,
#  ('<START>', '<START>', '<START>', 'nonsense'): 0.0001643477253162653,
#  ('<START>', '<START>', 'nonsense', ','): 0.9501994256541162,
#  ('<START>', 'nonsense', ',', 'how'): 0.5637956882651247,
#  ('nonsense', ',', 'how', 'can'): 0.5606496600136435,
#  (',', 'how', 'can', 'you'): 0.6879392975727905,
#  ('how', 'can', 'you', 'talk'): 0.18388874965695695,
#  ('can', 'you', 'talk', 'so'): 0.8099851095511594,
#  ('you', 'talk', 'so', '<END>'): 0.9252830614554922,
#  ('but', 'it', 'is', 'very'): 0.061542838425431165,
#  ('it', 'is', 'very', 'likely'): 0.05558466532773572,
#  ('is', 'very', 'likely', 'that'): 0.5591621171941339,
#  ('very', 'likely', 'that', 'he'): 0.6560141384772877,
#  ('likely', 'that', 'he', 'may'): 0.508774539583597,
#  ('that', 'he', 'may', 'fall'): 0.19696944349525478,
#  ('he', 'may', 'fall', 'in'): 0.8400705966815571,
#  ('may', 'fall', 'in', 'love'): 0.87695441111679,
#  ('fall', 'in', 'love', 'with'): 0.34645549559684896,
#  ('in', 'love', 'with', 'one'): 0.07203669929735809,
#  ('love', 'with', 'one', 'of'): 0.8513450706409984,
#  ('with', 'one', 'of', 'them'): 0.15074319210606948,
#  ('one', 'of', 'them', ','): 0.19877111024150929,
#  ('of', 'them', ',', 'and'): 0.25829510748997586,
#  ('them', ',', 'and', 'therefore'): 0.03546200420213609,
#  (',', 'and', 'therefore', 'you'): 0.1291442674084145,
#  ('and', 'therefore', 'you', 'must'): 0.6371001381251107,
#  ('therefore', 'you', 'must', 'visit'): 0.5062704511154431,
#  ('you', 'must', 'visit', 'him'): 0.7682529869531305,
#  ('must', 'visit', 'him', 'as'): 0.6067891190927381,
#  ('visit', 'him', 'as', 'soon'): 0.5948660689335437,
#  ('him', 'as', 'soon', 'as'): 0.944682400966209,
#  ('as', 'soon', 'as', 'he'): 0.17912158007579235,
#  ('soon', 'as', 'he', 'comes'): 0.0720554682384389,
#  ('as', 'he', 'comes', '<END>'): 0.6493662273815433,
#  ('<START>', '<START>', '<START>', 'i'): 0.08117487339120022,
#  ('<START>', '<START>', 'i', 'see'): 0.010032216748767041,
#  ('<START>', 'i', 'see', 'no'): 0.16896667010773678,
#  ('i', 'see', 'no', 'occasion'): 0.8905162253231865,
#  ('see', 'no', 'occasion', 'for'): 0.9158032569902386,
#  ('no', 'occasion', 'for', 'that'): 0.11245469372275933,
#  ('occasion', 'for', 'that', '<END>'): 0.5938886777735921,
#  ('<START>', '<START>', '<START>', 'bingley'): 0.015281034514607775,
#  ('<START>', '<START>', 'bingley', 'might'): 0.010686731697725698,
#  ('<START>', 'bingley', 'might', 'like'): 0.7517845379500587,
#  ('bingley', 'might', 'like', 'you'): 0.7715928584392546,
#  ('might', 'like', 'you', 'the'): 0.6532074149360891,
#  ('like', 'you', 'the', 'best'): 0.5372216421928432,
#  ('you', 'the', 'best', 'of'): 0.61387975358241,
#  ('the', 'best', 'of', 'the'): 0.405668656826364,
#  ('best', 'of', 'the', 'party'): 0.25469823156848875,
#  ('of', 'the', 'party', '<END>'): 0.49685626267029576,
#  ('<START>', 'my', 'dear', ','): 0.22470705971081362,
#  ('dear', ',', 'you', 'flatter'): 0.1455623765687487,
#  (',', 'you', 'flatter', 'me'): 0.7739924402336655,
#  ('you', 'flatter', 'me', '<END>'): 0.8347128880494197,
#  ('<START>', '<START>', 'i', 'certainly'): 0.006049722244463489,
#  ('<START>', 'i', 'certainly', 'have'): 0.4668224254886667,
#  ('i', 'certainly', 'have', 'had'): 0.34561106093831573,
#  ('certainly', 'have', 'had', 'my'): 0.5329947235081443,
#  ('have', 'had', 'my', 'share'): 0.5843737260238643,
#  ('had', 'my', 'share', 'of'): 0.8173668722966745,
#  ('my', 'share', 'of', 'beauty'): 0.2835864101552579,
#  ('share', 'of', 'beauty', ','): 0.9408884634474934,
#  ('of', 'beauty', ',', 'but'): 0.34928918346568644,
#  ('beauty', ',', 'but', 'i'): 0.30691434636584936,
#  (',', 'but', 'i', 'do'): 0.0425725068265979,
#  ('but', 'i', 'do', 'not'): 0.9255815103454333,
#  ('i', 'do', 'not', 'pretend'): 0.045024894339082695,
#  ('do', 'not', 'pretend', 'to'): 0.9966982590140396,
#  ('not', 'pretend', 'to', 'be'): 0.36949168960638845,
#  ('pretend', 'to', 'be', 'any'): 0.1296132474175614,
#  ('to', 'be', 'any', 'thing'): 0.5971909427979203,
#  ('be', 'any', 'thing', 'extraordinary'): 0.517433893517794,
#  ('any', 'thing', 'extraordinary', 'now'): 0.2630455058661823,
#  ('thing', 'extraordinary', 'now', '<END>'): 0.8522050779469414,
#  ('<START>', '<START>', '<START>', 'when'): 0.010024310863467754,
#  ('<START>', '<START>', 'when', 'a'): 0.021963596903173385,
#  ('<START>', 'when', 'a', 'woman'): 0.5647992168696949,
#  ('when', 'a', 'woman', 'has'): 0.5417099251667635,
#  ('a', 'woman', 'has', 'five'): 0.3762751596569762,
#  ('woman', 'has', 'five', 'grown'): 0.7556158264199107,
#  ('has', 'five', 'grown', 'up'): 0.8232063086881211,
#  ('five', 'grown', 'up', 'daughters'): 0.6272764289592243,
#  ('grown', 'up', 'daughters', ','): 0.9112047713543898,
#  ('up', 'daughters', ',', 'she'): 0.5360107176055869,
#  ('daughters', ',', 'she', 'ought'): 0.501426533856235,
#  (',', 'she', 'ought', 'to'): 0.8809522193105134,
#  ('she', 'ought', 'to', 'give'): 0.5192634209988214,
#  ('ought', 'to', 'give', 'over'): 0.5102024644582839,
#  ('to', 'give', 'over', 'thinking'): 0.6273300960460764,
#  ('give', 'over', 'thinking', 'of'): 0.8386553392895129,
#  ('over', 'thinking', 'of', 'her'): 0.6357909288177619,
#  ('thinking', 'of', 'her', 'own'): 0.26864842749813056,
#  ('of', 'her', 'own', 'beauty'): 0.059420980032556914,
#  ('her', 'own', 'beauty', '<END>'): 0.8699611784726654,
#  ('<START>', '<START>', '<START>', 'in'): 0.011348966333682717,
#  ('<START>', '<START>', 'in', 'such'): 0.028530569784235488,
#  ('<START>', 'in', 'such', 'cases'): 0.28297570448443926,
#  ('in', 'such', 'cases', ','): 0.3917085339676278,
#  ('such', 'cases', ',', 'a'): 0.7574107703945678,
#  ('cases', ',', 'a', 'woman'): 0.5125242821305537,
#  (',', 'a', 'woman', 'has'): 0.29170992516676353,
#  ('a', 'woman', 'has', 'not'): 0.40485445711969964,
#  ('woman', 'has', 'not', 'often'): 0.5194453201778321,
#  ('has', 'not', 'often', 'much'): 0.5329253764834767,
#  ('not', 'often', 'much', 'beauty'): 0.7508392374972246,
#  ('often', 'much', 'beauty', 'to'): 0.8064480961497553,
#  ('much', 'beauty', 'to', 'think'): 0.7540819518438582,
#  ('beauty', 'to', 'think', 'of'): 0.6041100453700228,
#  ('to', 'think', 'of', '<END>'): 0.0961350229786561,
#  ('<START>', '<START>', 'but', ','): 0.09405913740753899,
#  ('<START>', 'but', ',', 'my'): 0.20567871400595292,
#  ('but', ',', 'my', 'dear'): 0.7627072372288346,
#  (',', 'you', 'must', 'indeed'): 0.029038162726330835,
#  ('you', 'must', 'indeed', 'go'): 0.7533389552374874,
#  ('must', 'indeed', 'go', 'and'): 0.7901567893914345,
#  ('indeed', 'go', 'and', 'see'): 0.8344011111515894,
#  ('go', 'and', 'see', 'mr'): 0.298424973052399,
#  ('and', 'see', 'mr', '<END>'): 0.9999903099586013,
#  ('<START>', '<START>', 'bingley', 'when'): 0.01108951949393658,
#  ('<START>', 'bingley', 'when', 'he'): 0.7728065451293022,
#  ('bingley', 'when', 'he', 'comes'): 0.5140613614396988,
#  ('when', 'he', 'comes', 'into'): 0.5471716588500252,
#  ('he', 'comes', 'into', 'the'): 0.8611713926542162,
#  ('comes', 'into', 'the', 'neighbourhood'): 0.507275287362755,
#  ('into', 'the', 'neighbourhood', '<END>'): 0.6297372324462305,
#  ('<START>', 'it', 'is', 'more'): 0.013129315838238264,
#  ('it', 'is', 'more', 'than'): 0.6719704931737297,
#  ('is', 'more', 'than', 'i'): 0.30151935670156627,
#  ('more', 'than', 'i', 'engage'): 0.12096491761204757,
#  ('than', 'i', 'engage', 'for'): 0.8001954371410338,
#  ('i', 'engage', 'for', ','): 0.8145124605239474,
#  ('engage', 'for', ',', 'i'): 0.5474549850411187,
#  ('for', ',', 'i', 'assure'): 0.5086976302175188,
#  (',', 'i', 'assure', 'you'): 0.9980209627850737,
#  ('i', 'assure', 'you', '<END>'): 0.219411690153347,
#  ('<START>', '<START>', 'but', 'consider'): 0.0037376577836771016,
#  ('<START>', 'but', 'consider', 'your'): 0.6002428946662597,
#  ('but', 'consider', 'your', 'daughters'): 0.6264959497292958,
#  ('consider', 'your', 'daughters', '<END>'): 0.7392719925518616,
#  ('<START>', '<START>', '<START>', 'only'): 0.001315811899236037,
#  ('<START>', '<START>', 'only', 'think'): 0.5596536520276151,
#  ('<START>', 'only', 'think', 'what'): 0.3405833847011357,
#  ('only', 'think', 'what', 'an'): 0.254551522354143,
#  ('think', 'what', 'an', 'establishment'): 0.5640883713822028,
#  ('what', 'an', 'establishment', 'it'): 0.6303911401829398,
#  ('an', 'establishment', 'it', 'would'): 0.7618965445091905,
#  ('establishment', 'it', 'would', 'be'): 0.7111545252154041,
#  ('it', 'would', 'be', 'for'): 0.055932409379365534,
#  ('would', 'be', 'for', 'one'): 0.2754644153974084,
#  ('be', 'for', 'one', 'of'): 0.8017934275213312,
#  ('for', 'one', 'of', 'them'): 0.2112527577859948,
#  ('<START>', '<START>', '<START>', 'sir'): 0.0016434696228166828,
#  ('<START>', '<START>', 'sir', 'william'): 0.887605355834456,
#  ('<START>', 'sir', 'william', 'and'): 0.193577134888558,
#  ('sir', 'william', 'and', 'lady'): 0.409614755110296,
#  ('william', 'and', 'lady', 'lucas'): 0.7487304381278308,
#  ('and', 'lady', 'lucas', 'are'): 0.19012118661473346,
#  ('lady', 'lucas', 'are', 'determined'): 0.7519301308782431,
#  ('lucas', 'are', 'determined', 'to'): 0.9301895540842374,
#  ('are', 'determined', 'to', 'go'): 0.23133656203093889,
#  ('determined', 'to', 'go', ','): 0.3571473816220913,
#  ('to', 'go', ',', 'merely'): 0.21682505891574613,
#  ('go', ',', 'merely', 'on'): 0.640531565387979,
#  (',', 'merely', 'on', 'that'): 0.765318088207039,
#  ('merely', 'on', 'that', 'account'): 0.5187678658108668,
#  ('on', 'that', 'account', ','): 0.8584995213784301,
#  ('that', 'account', ',', 'for'): 0.5693060126421511,
#  ('account', ',', 'for', 'in'): 0.5163451399478738,
#  (',', 'for', 'in', 'general'): 0.21921232670383825,
#  ('for', 'in', 'general', 'you'): 0.5380721813859013,
#  ('in', 'general', 'you', 'know'): 0.7580221522661634,
#  ('general', 'you', 'know', 'they'): 0.512541276996642,
#  ('you', 'know', 'they', 'visit'): 0.6257951174690964,
#  ('know', 'they', 'visit', 'no'): 0.7587248723675813,
#  ('they', 'visit', 'no', 'new'): 0.7506805806443566,
#  ('visit', 'no', 'new', 'comers'): 0.7562669511806,
#  ('no', 'new', 'comers', '<END>'): 0.9924417677089981,
#  ('<START>', '<START>', '<START>', 'indeed'): 0.0018078173481329482,
#  ('<START>', '<START>', 'indeed', 'you'): 0.08922072987767868,
#  ('<START>', 'indeed', 'you', 'must'): 0.6371001381251107,
#  ('indeed', 'you', 'must', 'go'): 0.5143614334049642,
#  ('you', 'must', 'go', ','): 0.39881571520216,
#  ('must', 'go', ',', 'for'): 0.5568060126421511,
#  ('go', ',', 'for', 'it'): 0.5259715080947351,
#  (',', 'for', 'it', 'will'): 0.09967405377067778,
#  ('for', 'it', 'will', 'be'): 0.7126493182472009,
#  ('it', 'will', 'be', 'impossible'): 0.0744616739478356,
#  ('will', 'be', 'impossible', 'for'): 0.8000425441395449,
#  ('be', 'impossible', 'for', 'us'): 0.31104339662656416,
#  ('impossible', 'for', 'us', 'to'): 0.792042327469126,
#  ('for', 'us', 'to', 'visit'): 0.1569644778842178,
#  ('us', 'to', 'visit', 'him'): 0.5937719879567359,
#  ('to', 'visit', 'him', ','): 0.8495414596970057,
#  ('visit', 'him', ',', 'if'): 0.25903249237402604,
#  ('him', ',', 'if', 'you'): 0.360850655428447,
#  (',', 'if', 'you', 'do'): 0.09082604097978067,
#  ('if', 'you', 'do', 'not'): 0.8093024806138435,
#  ('you', 'do', 'not', '<END>'): 0.08283340655564661,
#  ('<START>', '<START>', 'you', 'are'): 0.15484441338831767,
#  ('<START>', 'you', 'are', 'over'): 0.025143568245571846,
#  ('you', 'are', 'over', 'scrupulous'): 0.7521129064261314,
#  ('are', 'over', 'scrupulous', 'surely'): 0.8750797702616464,
#  ('over', 'scrupulous', 'surely', '<END>'): 0.8986917677089981,
#  ('<START>', '<START>', 'i', 'dare'): 0.014224595772085593,
#  ('<START>', 'i', 'dare', 'say'): 0.9861351112547666,
#  ('i', 'dare', 'say', 'mr'): 0.06694983457992948,
#  ('dare', 'say', 'mr', '<END>'): 0.9999870799448016,
#  ('<START>', '<START>', 'i', 'desire'): 0.0020070810085129893,
#  ('<START>', 'i', 'desire', 'you'): 0.8549286388534354,
#  ('i', 'desire', 'you', 'will'): 0.8948592832516566,
#  ('desire', 'you', 'will', 'do'): 0.26481708818952293,
#  ('you', 'will', 'do', 'no'): 0.2899811346556419,
#  ('will', 'do', 'no', 'such'): 0.6331134411072008,
#  ('do', 'no', 'such', 'thing'): 0.5866170770969207,
#  ('no', 'such', 'thing', '<END>'): 0.9686990806578577,
#  ('<START>', '<START>', '<START>', 'lizzy'): 0.0019721574431032438,
#  ('<START>', '<START>', 'lizzy', 'is'): 0.16156487871630734,
#  ('<START>', 'lizzy', 'is', 'not'): 0.4051497575307986,
#  ('lizzy', 'is', 'not', 'a'): 0.5336398030492799,
#  ('is', 'not', 'a', 'bit'): 0.3058127949354013,
#  ('not', 'a', 'bit', 'better'): 0.4262922782386726,
#  ('a', 'bit', 'better', 'than'): 0.7677462242076154,
#  ('bit', 'better', 'than', 'the'): 0.5893997908624441,
#  ('better', 'than', 'the', 'others'): 0.517168193118658,
#  ('than', 'the', 'others', ';'): 0.5647307223727134,
#  ('the', 'others', ';', 'and'): 0.5921833606254373,
#  ('others', ';', 'and', 'i'): 0.2835186416131871,
#  (';', 'and', 'i', 'am'): 0.192763358178494,
#  ('and', 'i', 'am', 'sure'): 0.2608546648716944,
#  ('i', 'am', 'sure', 'she'): 0.05831947439197791,
#  ('am', 'sure', 'she', 'is'): 0.26156137300241583,
#  ('sure', 'she', 'is', 'not'): 0.5511523589363168,
#  ('she', 'is', 'not', 'half'): 0.12980478555668673,
#  ('is', 'not', 'half', 'so'): 0.7736042149828007,
#  ('not', 'half', 'so', 'handsome'): 0.551352836814268,
#  ('half', 'so', 'handsome', 'as'): 0.6735191353221659,
#  ('so', 'handsome', 'as', 'jane'): 0.31491571049830813,
#  ('handsome', 'as', 'jane', ','): 0.6784479857805359,
#  ('as', 'jane', ',', 'nor'): 0.5054845817630131,
#  ('jane', ',', 'nor', 'half'): 0.5109958052296103,
#  (',', 'nor', 'half', 'so'): 0.7736042149828007,
#  ('nor', 'half', 'so', 'good'): 0.5525381143145437,
#  ('half', 'so', 'good', 'humoured'): 0.5873752893379846,
#  ('so', 'good', 'humoured', 'as'): 0.6008388149820824,
#  ('good', 'humoured', 'as', 'lydia'): 0.7514885504847091,
#  ('humoured', 'as', 'lydia', '<END>'): 0.6472802586254668,
#  ('<START>', '<START>', 'but', 'you'): 0.03832335847753843,
#  ('<START>', 'but', 'you', 'are'): 0.15079408780271386,
#  ('but', 'you', 'are', 'always'): 0.25894523517698326,
#  ('you', 'are', 'always', 'giving'): 0.3362736651776218,
#  ('are', 'always', 'giving', 'her'): 0.6859833423330551,
#  ('always', 'giving', 'her', 'the'): 0.5863622379000422,
#  ('giving', 'her', 'the', 'preference'): 0.5211564865460262,
#  ('her', 'the', 'preference', '<END>'): 0.6529516360403406,
#  ('<START>', '<START>', '<START>', 'they'): 0.017747715420777944,
#  ('<START>', '<START>', 'they', 'have'): 0.06270744476506575,
#  ('<START>', 'they', 'have', 'none'): 0.09589774394697859,
#  ('they', 'have', 'none', 'of'): 0.7665440198893853,
#  ('have', 'none', 'of', 'them'): 0.5927815187698279,
#  ('none', 'of', 'them', 'much'): 0.17637407471433705,
#  ('of', 'them', 'much', 'to'): 0.6783502927626829,
#  ('them', 'much', 'to', 'recommend'): 0.5156004752391876,
#  ('much', 'to', 'recommend', 'them'): 0.5978935053012238,
#  ('to', 'recommend', 'them', ','): 0.47538016516660353,
#  ('recommend', 'them', ',', 'replied'): 0.5063222310875177,
#  ('them', ',', 'replied', 'he'): 0.5315845627749974,
#  (',', 'replied', 'he', ';'): 0.5664324038728967,
#  ('replied', 'he', ';', 'they'): 0.33636962397802067,
#  ('he', ';', 'they', 'are'): 0.7089693534472571,
#  (';', 'they', 'are', 'all'): 0.1636774503223819,
#  ('they', 'are', 'all', 'silly'): 0.19212973303552436,
#  ('are', 'all', 'silly', 'and'): 0.8184448787492022,
#  ('all', 'silly', 'and', 'ignorant'): 0.7502717370822425,
#  ('silly', 'and', 'ignorant', 'like'): 0.6375790105448689,
#  ('and', 'ignorant', 'like', 'other'): 0.7570900394021183,
#  ('ignorant', 'like', 'other', 'girls'): 0.627259603453166,
#  ('like', 'other', 'girls', ';'): 0.646719754798488,
#  ('other', 'girls', ';', 'but'): 0.7947344839548458,
#  ('girls', ';', 'but', 'lizzy'): 0.5021117720651651,
#  (';', 'but', 'lizzy', 'has'): 0.6287183632787058,
#  ('but', 'lizzy', 'has', 'something'): 0.7517156428900824,
#  ('lizzy', 'has', 'something', 'more'): 0.7702419279665574,
#  ('has', 'something', 'more', 'of'): 0.6904787419778209,
#  ('something', 'more', 'of', 'quickness'): 0.19054933793882253,
#  ('more', 'of', 'quickness', 'than'): 0.7965326526271006,
#  ('of', 'quickness', 'than', 'her'): 0.7764039566049776,
#  ('quickness', 'than', 'her', 'sisters'): 0.569939444203013,
#  ('than', 'her', 'sisters', '<END>'): 0.3673748024404141,
#  ('<START>', 'bennet', ',', 'how'): 0.01577791202477587,
#  ('bennet', ',', 'how', 'can'): 0.5606496600136435,
#  ('how', 'can', 'you', 'abuse'): 0.09183475894436861,
#  ('can', 'you', 'abuse', 'your'): 0.8202177728142949,
#  ('you', 'abuse', 'your', 'own'): 0.7582367941618462,
#  ('abuse', 'your', 'own', 'children'): 0.5379124732464655,
#  ('your', 'own', 'children', 'in'): 0.36487732534601425,
#  ('own', 'children', 'in', 'such'): 0.7563446145186482,
#  ('children', 'in', 'such', 'a'): 0.7049235187720478,
#  ('in', 'such', 'a', 'way'): 0.1386049205474764,
#  ('such', 'a', 'way', '<END>'): 0.4188407482587776,
#  ('<START>', '<START>', 'you', 'take'): 0.011427574621542374,
#  ('<START>', 'you', 'take', 'delight'): 0.31522109528441583,
#  ('you', 'take', 'delight', 'in'): 0.7993340469769644,
#  ('take', 'delight', 'in', 'vexing'): 0.5626313886489737,
#  ('delight', 'in', 'vexing', 'me'): 0.8827377153797065,
#  ('in', 'vexing', 'me', '<END>'): 0.8347128880494197,
#  ('<START>', '<START>', 'you', 'have'): 0.09904635749491321,
#  ('<START>', 'you', 'have', 'no'): 0.08812679602621627,
#  ('you', 'have', 'no', 'compassion'): 0.13526801768561267,
#  ('have', 'no', 'compassion', 'on'): 0.7873169715663334,
#  ('no', 'compassion', 'on', 'my'): 0.8396976206732496,
#  ('compassion', 'on', 'my', 'poor'): 0.2679081105297335,
#  ('on', 'my', 'poor', 'nerves'): 0.6197153906151992,
#  ('my', 'poor', 'nerves', '<END>'): 0.9986563142593774,
#  ('<START>', '<START>', 'you', 'mistake'): 0.005617659721859609,
#  ('<START>', 'you', 'mistake', 'me'): 0.7772814294830888,
#  ('you', 'mistake', 'me', ','): 0.8634925378692063,
#  ('mistake', 'me', ',', 'my'): 0.5240060377402289,
#  ('me', ',', 'my', 'dear'): 0.9251381581525564,
#  (',', 'my', 'dear', '<END>'): 0.059126934063205835,
#  ('<START>', '<START>', 'i', 'have'): 0.0990984157972614,
#  ('<START>', 'i', 'have', 'a'): 0.042251146677100726,
#  ('i', 'have', 'a', 'high'): 0.13595488647917864,
#  ('have', 'a', 'high', 'respect'): 0.6347024273795173,
#  ('a', 'high', 'respect', 'for'): 0.7893159592266166,
#  ('high', 'respect', 'for', 'your'): 0.5690348889216151,
#  ('respect', 'for', 'your', 'nerves'): 0.51516906451734,
#  ('for', 'your', 'nerves', '<END>'): 0.9969767070835992,
#  ('<START>', '<START>', 'they', 'are'): 0.0897554902617784,
#  ('<START>', 'they', 'are', 'my'): 0.06963259223398299,
#  ('they', 'are', 'my', 'old'): 0.7504213640372053,
#  ('are', 'my', 'old', 'friends'): 0.7640479629194237,
#  ('my', 'old', 'friends', '<END>'): 0.8542731932035736,
#  ('<START>', 'i', 'have', 'heard'): 0.06555117721362413,
#  ('i', 'have', 'heard', 'you'): 0.44373424638678094,
#  ('have', 'heard', 'you', 'mention'): 0.18208063874023,
#  ('heard', 'you', 'mention', 'them'): 0.7622089408145567,
#  ('you', 'mention', 'them', 'with'): 0.7617344078651791,
#  ('mention', 'them', 'with', 'consideration'): 0.5315491384811742,
#  ('them', 'with', 'consideration', 'these'): 0.763612795149968,
#  ('with', 'consideration', 'these', 'twenty'): 0.7525356602614102,
#  ('consideration', 'these', 'twenty', 'years'): 0.7862308931230437,
#  ('these', 'twenty', 'years', 'at'): 0.5978161511199945,
#  ('twenty', 'years', 'at', 'least'): 0.7604020926062055,
#  ('years', 'at', 'least', '<END>'): 0.6144092538461484,
#  ('<START>', '<START>', 'you', 'do'): 0.029214165379693263,
#  ('<START>', 'you', 'do', 'not'): 0.9403101937937159,
#  ('you', 'do', 'not', 'know'): 0.1673432774073606,
#  ('do', 'not', 'know', 'what'): 0.1552856667805119,
#  ('not', 'know', 'what', 'i'): 0.16761723840130843,
#  ('know', 'what', 'i', 'suffer'): 0.2672849053398317,
#  ('what', 'i', 'suffer', '<END>'): 0.867205185906694,
#  ('<START>', '<START>', 'it', 'will'): 0.02462020576368474,
#  ('<START>', 'it', 'will', 'be'): 0.4112438384419564,
#  ('it', 'will', 'be', 'no'): 0.041360698991589076,
#  ('will', 'be', 'no', 'use'): 0.5390568472745874,
#  ('be', 'no', 'use', 'to'): 0.8254124894497397,
#  ('no', 'use', 'to', 'us'): 0.5846635379246348,
#  ('use', 'to', 'us', ','): 0.7244612973800608,
#  ('to', 'us', ',', 'if'): 0.13539404741382494,
#  ('us', ',', 'if', 'twenty'): 0.2548149332372808,
#  (',', 'if', 'twenty', 'such'): 0.767070835992342,
#  ('if', 'twenty', 'such', 'should'): 0.7529258713628155,
#  ('twenty', 'such', 'should', 'come'): 0.753413431727971,
#  ('such', 'should', 'come', 'since'): 0.602193610330177,
#  ('should', 'come', 'since', 'you'): 0.775406224014233,
#  ('come', 'since', 'you', 'will'): 0.7107467098529818,
#  ('since', 'you', 'will', 'not'): 0.7380325201431573,
#  ('you', 'will', 'not', 'visit'): 0.04105394513465416,
#  ('will', 'not', 'visit', 'them'): 0.6400233992767497,
#  ('not', 'visit', 'them', '<END>'): 0.7664929147817499,
#  ('<START>', '<START>', '<START>', 'depend'): 0.0001644698108517811,
#  ('<START>', '<START>', 'depend', 'upon'): 0.8849099209660792,
#  ('<START>', 'depend', 'upon', 'it'): 0.7331208925312643,
#  ('depend', 'upon', 'it', ','): 0.702029809248364,
#  ('upon', 'it', ',', 'my'): 0.08496880238762114,
#  ('it', ',', 'my', 'dear'): 0.8502763163051128,
#  ('my', 'dear', ',', 'that'): 0.042545494216894325,
#  ('dear', ',', 'that', 'when'): 0.5047317995465106,
#  (',', 'that', 'when', 'there'): 0.25370771556156607,
#  ('that', 'when', 'there', 'are'): 0.348034736607412,
#  ('when', 'there', 'are', 'twenty'): 0.5161953294339887,
#  ('there', 'are', 'twenty', ','): 0.9010468897195125,
#  ('are', 'twenty', ',', 'i'): 0.8441366566940791,
#  ('twenty', ',', 'i', 'will'): 0.2626426939269917,
#  (',', 'i', 'will', 'visit'): 0.07228973328526407,
#  ('i', 'will', 'visit', 'them'): 0.3900233992767496,
#  ('will', 'visit', 'them', 'all'): 0.6101682967008504,
#  ('visit', 'them', 'all', '<END>'): 0.6297098261768013,
#  ('<START>', '<START>', 'bennet', 'was'): 0.14758713012620128,
#  ('<START>', 'bennet', 'was', 'so'): 0.036103959969789615,
#  ('bennet', 'was', 'so', 'odd'): 0.5103596427628744,
#  ('was', 'so', 'odd', 'a'): 0.8084627384244487,
#  ('so', 'odd', 'a', 'mixture'): 0.7505816792209623,
#  ('odd', 'a', 'mixture', 'of'): 0.9932306069630575,
#  ('a', 'mixture', 'of', 'quick'): 0.1606009496248005,
#  ('mixture', 'of', 'quick', 'parts'): 0.7639420690633199,
#  ('of', 'quick', 'parts', ','): 0.9586657094235269,
#  ('quick', 'parts', ',', 'sarcastic'): 0.7500307250342568,
#  ('parts', ',', 'sarcastic', 'humour'): 0.875418793873644,
#  (',', 'sarcastic', 'humour', ','): 0.9320599098837772,
#  ('sarcastic', 'humour', ',', 'reserve'): 0.5385011525835876,
#  ('humour', ',', 'reserve', ','): 0.9751994256541161,
#  (',', 'reserve', ',', 'and'): 0.6563998811980807,
#  ('reserve', ',', 'and', 'caprice'): 0.2503299534572136,
#  (',', 'and', 'caprice', ','): 0.8336657094235269,
#  ('and', 'caprice', ',', 'that'): 0.763996592757243,
#  ('caprice', ',', 'that', 'the'): 0.53306913583025,
#  (',', 'that', 'the', 'experience'): 0.033643432140262816,
#  ('that', 'the', 'experience', 'of'): 0.8765754626675175,
#  ('the', 'experience', 'of', 'three'): 0.750500813909132,
#  ('experience', 'of', 'three', 'and'): 0.6744455486271826,
#  ('of', 'three', 'and', 'twenty'): 0.7504284020289284,
#  ('three', 'and', 'twenty', 'years'): 0.6521731698422828,
#  ('and', 'twenty', 'years', 'had'): 0.35219147471633894,
#  ('twenty', 'years', 'had', 'been'): 0.7880914017353777,
#  ('years', 'had', 'been', 'insufficient'): 0.5020665494827028,
#  ('had', 'been', 'insufficient', 'to'): 0.8518101201871942,
#  ('been', 'insufficient', 'to', 'make'): 0.6304791078099568,
#  ('insufficient', 'to', 'make', 'his'): 0.5276566095778278,
#  ('to', 'make', 'his', 'wife'): 0.19168967945372356,
#  ('make', 'his', 'wife', 'understand'): 0.517049926140476,
#  ('his', 'wife', 'understand', 'his'): 0.7772717014024001,
#  ('wife', 'understand', 'his', 'character'): 0.8354345725087629,
#  ('understand', 'his', 'character', '<END>'): 0.7489150335353272,
#  ('<START>', '<START>', '<START>', 'her'): 0.012172169986690231,
#  ('<START>', '<START>', 'her', 'mind'): 0.023191868362714807,
#  ('<START>', 'her', 'mind', 'was'): 0.34017899055502154,
#  ('her', 'mind', 'was', 'less'): 0.2869853926986825,
#  ('mind', 'was', 'less', 'difficult'): 0.5523037101423762,
#  ('was', 'less', 'difficult', 'to'): 0.860025626196554,
#  ('less', 'difficult', 'to', 'develope'): 0.5833979506063734,
#  ('difficult', 'to', 'develope', '<END>'): 0.9924417677089981,
#  ('<START>', '<START>', '<START>', 'she'): 0.04305605952481957,
#  ('<START>', '<START>', 'she', 'was'): 0.16247028312887626,
#  ('<START>', 'she', 'was', 'a'): 0.05113278717356892,
#  ('she', 'was', 'a', 'woman'): 0.11633083403552687,
#  ('was', 'a', 'woman', 'of'): 0.5627554632707553,
#  ('a', 'woman', 'of', 'mean'): 0.5627862913563404,
#  ('woman', 'of', 'mean', 'understanding'): 0.7556688909852668,
#  ('of', 'mean', 'understanding', ','): 0.9169325675388216,
#  ('mean', 'understanding', ',', 'little'): 0.5631292542689703,
#  ('understanding', ',', 'little', 'information'): 0.6263929114918266,
#  (',', 'little', 'information', ','): 0.8941357979926902,
#  ('little', 'information', ',', 'and'): 0.6150998854410064,
#  ('information', ',', 'and', 'uncertain'): 0.25029422503686605,
#  (',', 'and', 'uncertain', 'temper'): 0.812918793873644,
#  ('and', 'uncertain', 'temper', '<END>'): 0.8660914630380633,
#  ('<START>', '<START>', 'when', 'she'): 0.11867602664210322,
#  ('<START>', 'when', 'she', 'was'): 0.21445109251493785,
#  ('when', 'she', 'was', 'discontented'): 0.11280279272560925,
#  ('she', 'was', 'discontented', 'she'): 0.8411175813656668,
#  ('was', 'discontented', 'she', 'fancied'): 0.7503233098872235,
#  ('discontented', 'she', 'fancied', 'herself'): 0.6539685705169113,
#  ('she', 'fancied', 'herself', 'nervous'): 0.7510022101598361,
#  ('fancied', 'herself', 'nervous', '<END>'): 0.886378658036284,
#  ('<START>', '<START>', '<START>', 'the'): 0.03830997462743457,
#  ('<START>', '<START>', 'the', 'business'): 0.00774000962320923,
#  ('<START>', 'the', 'business', 'of'): 0.3724743561054984,
#  ('the', 'business', 'of', 'her'): 0.5086327430542095,
#  ('business', 'of', 'her', 'life'): 0.6728632814317256,
#  ('of', 'her', 'life', 'was'): 0.15332171551061147,
#  ('her', 'life', 'was', 'to'): 0.6252592974571307,
#  ('life', 'was', 'to', 'get'): 0.5075041512109248,
#  ('was', 'to', 'get', 'her'): 0.5400017161850399,
#  ('to', 'get', 'her', 'daughters'): 0.7517487142143102,
#  ('get', 'her', 'daughters', 'married'): 0.5272551162241785,
#  ('her', 'daughters', 'married', ';'): 0.8580386992923068,
#  ('daughters', 'married', ';', 'its'): 0.3060120187194214,
#  ('married', ';', 'its', 'solace'): 0.6264967544359817,
#  (';', 'its', 'solace', 'was'): 0.9065491384811742,
#  ('its', 'solace', 'was', 'visiting'): 0.7501584063489567,
#  ('solace', 'was', 'visiting', 'and'): 0.8434109763880026,
#  ('was', 'visiting', 'and', 'news'): 0.7503031623255731,
#  ('visiting', 'and', 'news', '<END>'): 0.8697092373962987,
#  ('<START>', 'bennet', 'was', 'among'): 0.028908188822738365,
#  ('bennet', 'was', 'among', 'the'): 0.8475220993169302,
#  ('was', 'among', 'the', 'earliest'): 0.5502452533064095,
#  ('among', 'the', 'earliest', 'of'): 0.6515754626675175,
#  ('the', 'earliest', 'of', 'those'): 0.7510958332803974,
#  ('earliest', 'of', 'those', 'who'): 0.5999021149331114,
#  ('of', 'those', 'who', 'waited'): 0.1959678028370137,
#  ('those', 'who', 'waited', 'on'): 0.8847343892015238,
#  ('who', 'waited', 'on', 'mr'): 0.33961068466901345,
#  ('waited', 'on', 'mr', '<END>'): 0.9999935399724009,
#  ('<START>', '<START>', '<START>', 'he'): 0.03237480795049898,
#  ('<START>', '<START>', 'he', 'had'): 0.07132176429960288,
#  ('<START>', 'he', 'had', 'always'): 0.044557002518302996,
#  ('he', 'had', 'always', 'intended'): 0.5251954751268727,
#  ('had', 'always', 'intended', 'to'): 0.8894555109855047,
#  ('always', 'intended', 'to', 'visit'): 0.5234417506114906,
#  ('intended', 'to', 'visit', 'him'): 0.5937719879567359,
#  ('visit', 'him', ',', 'though'): 0.26253355392786504,
#  ('him', ',', 'though', 'to'): 0.20373812085528437,
#  (',', 'though', 'to', 'the'): 0.7865990983420932,
#  ('though', 'to', 'the', 'last'): 0.5069389707608395,
#  ('to', 'the', 'last', 'always'): 0.14027322242175094,
#  ('the', 'last', 'always', 'assuring'): 0.7513233886407147,
#  ('last', 'always', 'assuring', 'his'): 0.8033264199106573,
#  ('always', 'assuring', 'his', 'wife'): 0.7541896794537235,
#  ('assuring', 'his', 'wife', 'that'): 0.5311774123547918,
#  ('his', 'wife', 'that', 'he'): 0.7810141384772877,
#  ('wife', 'that', 'he', 'should'): 0.5398634111725936,
#  ('that', 'he', 'should', 'not'): 0.16751641796448924,
#  ('he', 'should', 'not', 'go'): 0.18040115684198363,
#  ('should', 'not', 'go', ';'): 0.5529116354871723,
#  ('not', 'go', ';', 'and'): 0.9318003671227146,
#  ('go', ';', 'and', 'till'): 0.1692183446036683,
#  (';', 'and', 'till', 'the'): 0.518332719383352,
#  ('and', 'till', 'the', 'evening'): 0.2868109055695398,
#  ('till', 'the', 'evening', 'after'): 0.26146599432977286,
#  ('the', 'evening', 'after', 'the'): 0.8145115177532405,
#  ('evening', 'after', 'the', 'visit'): 0.514663486960833,
#  ('after', 'the', 'visit', 'was'): 0.6630117383148653,
#  ('the', 'visit', 'was', 'paid'): 0.48922063908287466,
#  ('visit', 'was', 'paid', ','): 0.9611848361050659,
#  ('was', 'paid', ',', 'she'): 0.32578344487831423,
#  ('paid', ',', 'she', 'had'): 0.5405372067708532,
#  (',', 'she', 'had', 'no'): 0.10818091134499863,
#  ('she', 'had', 'no', 'knowledge'): 0.05505609524167673,
#  ('had', 'no', 'knowledge', 'of'): 0.8957318711584321,
#  ('no', 'knowledge', 'of', 'it'): 0.5801203183122551,
#  ('knowledge', 'of', 'it', '<END>'): 0.42704726453388014,
#  ('<START>', '<START>', 'it', 'was'): 0.3585079611592929,
#  ('<START>', 'it', 'was', 'then'): 0.012318262627353298,
#  ('it', 'was', 'then', 'disclosed'): 0.27027800113676426,
#  ('was', 'then', 'disclosed', 'in'): 0.9080847160178686,
#  ('then', 'disclosed', 'in', 'the'): 0.8194559946100874,
#  ('disclosed', 'in', 'the', 'following'): 0.5025329071546878,
#  ('in', 'the', 'following', 'manner'): 0.7021112241788694,
#  ('the', 'following', 'manner', '<END>'): 0.45435531633806914,
#  ('<START>', '<START>', '<START>', 'observing'): 0.00016437824670014424,
#  ('<START>', '<START>', 'observing', 'his'): 0.794948326597178,
#  ('<START>', 'observing', 'his', 'second'): 0.6260895881089533,
#  ('observing', 'his', 'second', 'daughter'): 0.7011495529239427,
#  ('his', 'second', 'daughter', 'employed'): 0.2527439254516884,
#  ('second', 'daughter', 'employed', 'in'): 0.8685635370134014,
#  ('daughter', 'employed', 'in', 'trimming'): 0.583464721982307,
#  ('employed', 'in', 'trimming', 'a'): 0.9095205807275049,
#  ('in', 'trimming', 'a', 'hat'): 0.7501270527614732,
#  ('trimming', 'a', 'hat', ','): 0.9794990427568603,
#  ('a', 'hat', ',', 'he'): 0.7583133139263393,
#  ('hat', ',', 'he', 'suddenly'): 0.5047479169723214,
#  (',', 'he', 'suddenly', 'addressed'): 0.3508250262233274,
#  ('he', 'suddenly', 'addressed', 'her'): 0.6671368277542495,
#  ('suddenly', 'addressed', 'her', 'with'): 0.7605894288253511,
#  ('addressed', 'her', 'with', ','): 0.5692331650580421,
#  ('her', 'with', ',', 'i'): 0.5578716517077853,
#  ('with', ',', 'i', 'hope'): 0.5237503652245749,
#  (',', 'i', 'hope', 'mr'): 0.044337389765439335,
#  ('i', 'hope', 'mr', '<END>'): 0.9999709298758038,
#  ('<START>', '<START>', 'bingley', 'will'): 0.03147943129398931,
#  ('<START>', 'bingley', 'will', 'like'): 0.2512476908608471,
#  ('bingley', 'will', 'like', 'it'): 0.7774592659379519,
#  ('will', 'like', 'it', 'lizzy'): 0.5631143094772302,
#  ('like', 'it', 'lizzy', '<END>'): 0.8327139487759788,
#  ('<START>', '<START>', '<START>', 'we'): 0.008052077116904812,
#  ('<START>', '<START>', 'we', 'are'): 0.1026960862321186,
#  ('<START>', 'we', 'are', 'not'): 0.43033857891571126,
#  ('we', 'are', 'not', 'in'): 0.14949561790209115,
#  ('are', 'not', 'in', 'a'): 0.5498204406869402,
#  ('not', 'in', 'a', 'way'): 0.25658686209254045,
#  ('in', 'a', 'way', 'to'): 0.7492198148199773,
#  ('a', 'way', 'to', 'know'): 0.27221332829172884,
#  ('way', 'to', 'know', 'what'): 0.5765040144455336,
#  ('to', 'know', 'what', 'mr'): 0.11876480424145783,
#  ('know', 'what', 'mr', '<END>'): 0.9999958471251148,
#  ('<START>', '<START>', 'bingley', 'likes'): 0.020271261131401465,
#  ('<START>', 'bingley', 'likes', ','): 0.5349992022973835,
#  ('bingley', 'likes', ',', 'said'): 0.7563977663630815,
#  ('likes', ',', 'said', 'her'): 0.5401441959891138,
#  (',', 'said', 'her', 'mother'): 0.19717021011712144,
#  ('said', 'her', 'mother', 'resentfully'): 0.11864124553033296,
#  ('her', 'mother', 'resentfully', ','): 0.9794990427568603,
#  ('mother', 'resentfully', ',', 'since'): 0.7504898781367894,
#  ('resentfully', ',', 'since', 'we'): 0.5365249198735075,
#  (',', 'since', 'we', 'are'): 0.6104488867488829,
#  ('since', 'we', 'are', 'not'): 0.573784771887615,
#  ('we', 'are', 'not', 'to'): 0.1781875958547465,
#  ('are', 'not', 'to', 'visit'): 0.25634565796034814,
#  ('not', 'to', 'visit', '<END>'): 0.620736381784563,
#  ('<START>', 'but', 'you', 'forget'): 0.06927320429231557,
#  ('but', 'you', 'forget', ','): 0.7919556893537916,
#  ('you', 'forget', ',', 'mama'): 0.625095637323505,
#  ('forget', ',', 'mama', ','): 1.008399808551372,
#  (',', 'mama', ',', 'said'): 0.23556443302974817,
#  ('mama', ',', 'said', 'elizabeth'): 0.5744584172584661,
#  (',', 'said', 'elizabeth', ','): 0.5870669592114387,
#  ('said', 'elizabeth', ',', 'that'): 0.08685151687979897,
#  ('elizabeth', ',', 'that', 'we'): 0.07222027259702495,
#  (',', 'that', 'we', 'shall'): 0.20392943070390146,
#  ('that', 'we', 'shall', 'meet'): 0.26670392240643975,
#  ('we', 'shall', 'meet', 'him'): 0.7763713233161222,
#  ('shall', 'meet', 'him', 'at'): 0.5930604845322824,
#  ('meet', 'him', 'at', 'the'): 0.5604068461992072,
#  ('him', 'at', 'the', 'assemblies'): 0.5035975370016996,
#  ('at', 'the', 'assemblies', ','): 1.0279993618379069,
#  ('the', 'assemblies', ',', 'and'): 0.8672999108985606,
#  ('assemblies', ',', 'and', 'that'): 0.2669178846201169,
#  (',', 'and', 'that', 'mrs'): 0.024070524455554167,
#  ('and', 'that', 'mrs', '<END>'): 0.9999784050505971,
#  ('<START>', 'long', 'has', 'promised'): 0.3345178052658465,
#  ('long', 'has', 'promised', 'to'): 0.871366933818837,
#  ('has', 'promised', 'to', 'introduce'): 0.5298982947617141,
#  ('promised', 'to', 'introduce', 'him'): 0.6114618470234296,
#  ('to', 'introduce', 'him', '<END>'): 0.4489037475378797,
#  ('<START>', '<START>', 'i', 'do'): 0.062199571502150365,
#  ('<START>', 'i', 'do', 'not'): 0.8146180059116762,
#  ('i', 'do', 'not', 'believe'): 0.07544029710323219,
#  ('do', 'not', 'believe', 'mrs'): 0.14074639118866383,
#  ('not', 'believe', 'mrs', '<END>'): 0.99992441767709,
#  ('<START>', '<START>', 'long', 'will'): 0.0922589894926737,
#  ('<START>', 'long', 'will', 'do'): 0.7568135559063581,
#  ('long', 'will', 'do', 'any'): 0.5408276454914966,
#  ('will', 'do', 'any', 'such'): 0.5870881009978085,
#  ('do', 'any', 'such', 'thing'): 0.5870275450673691,
#  ('any', 'such', 'thing', '<END>'): 0.9373981613157153,
#  ('<START>', '<START>', 'she', 'has'): 0.029407945884972794,
#  ('<START>', 'she', 'has', 'two'): 0.08381276036935766,
#  ('she', 'has', 'two', 'nieces'): 0.6264798023403827,
#  ('has', 'two', 'nieces', 'of'): 0.8321797927850145,
#  ('two', 'nieces', 'of', 'her'): 0.6527647949199822,
#  ('nieces', 'of', 'her', 'own'): 0.5186484274981306,
#  ('of', 'her', 'own', '<END>'): 0.14839993737291257,
#  ('<START>', '<START>', 'she', 'is'): 0.0669637795231851,
#  ('<START>', 'she', 'is', 'a'): 0.24902383509816273,
#  ('she', 'is', 'a', 'selfish'): 0.1038517324196383,
#  ('is', 'a', 'selfish', ','): 0.8222718570516911,
#  ('a', 'selfish', ',', 'hypocritical'): 0.6250341872549914,
#  ('selfish', ',', 'hypocritical', 'woman'): 0.8134373005743458,
#  (',', 'hypocritical', 'woman', ','): 0.8870143538846926,
#  ('hypocritical', 'woman', ',', 'and'): 0.6286221034203029,
#  ('woman', ',', 'and', 'i'): 0.19128593019079482,
#  ('i', 'have', 'no', 'opinion'): 0.05966581258430215,
#  ('have', 'no', 'opinion', 'of'): 0.8530869983336878,
#  ('no', 'opinion', 'of', 'her'): 0.5632615071599861,
#  ('opinion', 'of', 'her', '<END>'): 0.22094435049724495,
#  ('<START>', '<START>', 'bennet', ';'): 0.0259305957664493,
#  ('<START>', 'bennet', ';', 'and'): 0.661600326331302,
#  ('bennet', ';', 'and', 'i'): 0.20018530827985373,
#  ('and', 'i', 'am', 'glad'): 0.05020645709366753,
#  ('i', 'am', 'glad', 'to'): 0.18495658563941908,
#  ('am', 'glad', 'to', 'find'): 0.5514906756431615,
#  ('glad', 'to', 'find', 'that'): 0.4895294077496144,
#  ('to', 'find', 'that', 'you'): 0.11857929822552246,
#  ('find', 'that', 'you', 'do'): 0.5089717550724191,
#  ('that', 'you', 'do', 'not'): 0.8209305813811478,
#  ('you', 'do', 'not', 'depend'): 0.04285098632747945,
#  ('do', 'not', 'depend', 'on'): 0.7047533871680329,
#  ('not', 'depend', 'on', 'her'): 0.5553814691108961,
#  ('depend', 'on', 'her', 'serving'): 0.508572731489257,
#  ('on', 'her', 'serving', 'you'): 0.8993897574984047,
#  ('her', 'serving', 'you', '<END>'): 0.8020920503666422,
#  ('<START>', '<START>', '<START>', 'dont'): 0.00032861914717283316,
#  ('<START>', '<START>', 'dont', 'keep'): 0.4066887364390555,
#  ('<START>', 'dont', 'keep', 'coughing'): 0.7562679483088705,
#  ('dont', 'keep', 'coughing', 'so'): 0.8853701340140396,
#  ('keep', 'coughing', 'so', ','): 0.862886823122183,
#  ('coughing', 'so', ',', 'kitty'): 0.5150361800531629,
#  ('so', ',', 'kitty', ','): 0.8994832420167456,
#  (',', 'kitty', ',', 'for'): 0.23246776079161183,
#  ('kitty', ',', 'for', 'heavens'): 0.2529638863948311,
#  (',', 'for', 'heavens', 'sake'): 0.900212720697724,
#  ('for', 'heavens', 'sake', '<END>'): 0.44197670708359926,
#  ('<START>', '<START>', '<START>', 'have'): 0.0016484140870050737,
#  ('<START>', '<START>', 'have', 'a'): 0.09967056173675826,
#  ('<START>', 'have', 'a', 'little'): 0.5482919981561338,
#  ('have', 'a', 'little', 'compassion'): 0.13172019410879082,
#  ('a', 'little', 'compassion', 'on'): 0.7873169715663334,
#  ('little', 'compassion', 'on', 'my'): 0.8396976206732496,
#  ...}

# %%
log_probabilities_witten = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}
for i in range(1, 5):
    for key in witten_bell_probabilities[i].keys():
        log_probabilities_witten[i].update(
            {key: math.log(witten_bell_probabilities[i][key])})

# %%
log_probabilities_witten[4]
# Out:
# {('<START>', '<START>', '<START>', 'pride'): -7.327022832869389,
#  ('<START>', '<START>', 'pride', '&'): -0.875387632945835,
#  ('<START>', 'pride', '&', 'prejudice'): -0.05712713187368684,
#  ('pride', '&', 'prejudice', '<END>'): -0.025168761199557722,
#  ('<START>', '<START>', '<START>', 'it'): -3.395431822425009,
#  ('<START>', '<START>', 'it', 'is'): -1.1730312492677681,
#  ('<START>', 'it', 'is', 'a'): -1.8967915764230894,
#  ('it', 'is', 'a', 'truth'): -3.35146186750174,
#  ('is', 'a', 'truth', 'universally'): -0.2775838755866481,
#  ('a', 'truth', 'universally', 'acknowledged'): -0.23321188264117867,
#  ('truth', 'universally', 'acknowledged', ','): -0.06597623702209784,
#  ('universally', 'acknowledged', ',', 'that'): -0.5047884407128879,
#  ('acknowledged', ',', 'that', 'a'): -1.3444384139822547,
#  (',', 'that', 'a', 'single'): -2.091598423664786,
#  ('that', 'a', 'single', 'man'): -0.48702779960706183,
#  ('a', 'single', 'man', 'in'): -0.9180486746764418,
#  ('single', 'man', 'in', 'possession'): -0.6055548287404787,
#  ('man', 'in', 'possession', 'of'): -0.04876193816751445,
#  ('in', 'possession', 'of', 'a'): -0.7205271935266366,
#  ('possession', 'of', 'a', 'good'): -1.3583337504999977,
#  ('of', 'a', 'good', 'fortune'): -0.667772601659124,
#  ('a', 'good', 'fortune', ','): -0.19414311550311686,
#  ('good', 'fortune', ',', 'must'): -1.2989060888933703,
#  ('fortune', ',', 'must', 'be'): -0.4099669449322313,
#  (',', 'must', 'be', 'in'): -1.9437775000723196,
#  ('must', 'be', 'in', 'want'): -2.21582943781425,
#  ('be', 'in', 'want', 'of'): -0.14577462690306967,
#  ('in', 'want', 'of', 'a'): -0.6246729991339968,
#  ('want', 'of', 'a', 'wife'): -0.6862276659987516,
#  ('of', 'a', 'wife', '<END>'): -0.4006120902038749,
#  ('<START>', '<START>', '<START>', 'however'): -6.767145147049543,
#  ('<START>', '<START>', 'however', 'little'): -1.2988252458673022,
#  ('<START>', 'however', 'little', 'known'): -1.0937425597560408,
#  ('however', 'little', 'known', 'the'): -0.20539870515963196,
#  ('little', 'known', 'the', 'feelings'): -0.5369680232358046,
#  ('known', 'the', 'feelings', 'or'): -0.612292316179715,
#  ('the', 'feelings', 'or', 'views'): -0.28680922873304576,
#  ('feelings', 'or', 'views', 'of'): -0.15619540458046943,
#  ('or', 'views', 'of', 'such'): -0.5678779870821532,
#  ('views', 'of', 'such', 'a'): -0.35477272855661474,
#  ('of', 'such', 'a', 'man'): -2.9361727169663068,
#  ('such', 'a', 'man', 'may'): -1.5522756949862608,
#  ('a', 'man', 'may', 'be'): -0.22200317962865213,
#  ('man', 'may', 'be', 'on'): -0.6636708582604648,
#  ('may', 'be', 'on', 'his'): -0.5535499884714893,
#  ('be', 'on', 'his', 'first'): -0.6472011027990132,
#  ('on', 'his', 'first', 'entering'): -1.5233091459385166,
#  ('his', 'first', 'entering', 'a'): -0.23086446372287364,
#  ('first', 'entering', 'a', 'neighbourhood'): -0.28716985862073696,
#  ('entering', 'a', 'neighbourhood', ','): -0.07216452887168129,
#  ('a', 'neighbourhood', ',', 'this'): -0.6452294978258805,
#  ('neighbourhood', ',', 'this', 'truth'): -0.6593801972174874,
#  (',', 'this', 'truth', 'is'): -0.26573721844029385,
#  ('this', 'truth', 'is', 'so'): -0.2774148757058659,
#  ('truth', 'is', 'so', 'well'): -0.6307643844778227,
#  ('is', 'so', 'well', 'fixed'): -0.6658282361378804,
#  ('so', 'well', 'fixed', 'in'): -0.23383919271904155,
#  ('well', 'fixed', 'in', 'the'): -0.3646264814876975,
#  ('fixed', 'in', 'the', 'minds'): -0.6911006957953368,
#  ('in', 'the', 'minds', 'of'): -0.1735963989018875,
#  ('the', 'minds', 'of', 'the'): -0.21822884463570302,
#  ('minds', 'of', 'the', 'surrounding'): -0.6914907148414451,
#  ('of', 'the', 'surrounding', 'families'): -0.20754119081390104,
#  ('the', 'surrounding', 'families', ','): -0.05313810789757153,
#  ('surrounding', 'families', ',', 'that'): -0.26919194956738984,
#  ('families', ',', 'that', 'he'): -0.5843780074646607,
#  (',', 'that', 'he', 'is'): -2.624756880628564,
#  ('that', 'he', 'is', 'considered'): -2.800931310493879,
#  ('he', 'is', 'considered', 'as'): -0.23853375445559669,
#  ('is', 'considered', 'as', 'the'): -0.48559403710410154,
#  ('considered', 'as', 'the', 'rightful'): -0.6777761155743932,
#  ('as', 'the', 'rightful', 'property'): -0.1333262901295294,
#  ('the', 'rightful', 'property', 'of'): -0.19235710468690317,
#  ('rightful', 'property', 'of', 'some'): -0.2844621247201676,
#  ('property', 'of', 'some', 'one'): -0.6232758423992028,
#  ('of', 'some', 'one', 'or'): -0.965093027844469,
#  ('some', 'one', 'or', 'other'): -0.5210933658087973,
#  ('one', 'or', 'other', 'of'): -0.5827100821655657,
#  ('or', 'other', 'of', 'their'): -0.27745267755488556,
#  ('other', 'of', 'their', 'daughters'): -0.6841210335822835,
#  ('of', 'their', 'daughters', '<END>'): -0.1458677535248702,
#  ('<START>', '<START>', '<START>', 'my'): -4.1492112776917045,
#  ('<START>', '<START>', 'my', 'dear'): -1.0890104639223357,
#  ('<START>', 'my', 'dear', 'mr'): -2.1412279305037707,
#  ('my', 'dear', 'mr', '<END>'): -2.373074178709348e-06,
#  ('<START>', '<START>', '<START>', 'bennet'): -3.537638705690139,
#  ('<START>', '<START>', 'bennet', ','): -1.1437216763708191,
#  ('<START>', 'bennet', ',', 'said'): -3.2285266142218623,
#  ('bennet', ',', 'said', 'his'): -1.9067296474231272,
#  (',', 'said', 'his', 'lady'): -0.9751233623875496,
#  ('said', 'his', 'lady', 'to'): -0.42963408879989445,
#  ('his', 'lady', 'to', 'him'): -0.4594798251377887,
#  ('lady', 'to', 'him', 'one'): -0.674924535716674,
#  ('to', 'him', 'one', 'day'): -0.4589157495041845,
#  ('him', 'one', 'day', ','): -0.2397710683933746,
#  ('one', 'day', ',', 'have'): -2.190564533151037,
#  ('day', ',', 'have', 'you'): -0.5636359318943028,
#  (',', 'have', 'you', 'heard'): -0.7931798646425425,
#  ('have', 'you', 'heard', 'that'): -1.5045302129593698,
#  ('you', 'heard', 'that', 'netherfield'): -0.5377904307187106,
#  ('heard', 'that', 'netherfield', 'park'): -0.46536054403489624,
#  ('that', 'netherfield', 'park', 'is'): -0.2645555111298168,
#  ('netherfield', 'park', 'is', 'let'): -0.2864816232075675,
#  ('park', 'is', 'let', 'at'): -0.2771573602388655,
#  ('is', 'let', 'at', 'last'): -0.27351015185940974,
#  ('let', 'at', 'last', '<END>'): -0.4591031258062345,
#  ('<START>', '<START>', 'bennet', 'replied'): -5.1632774344010315,
#  ('<START>', 'bennet', 'replied', 'that'): -0.26365023186871955,
#  ('bennet', 'replied', 'that', 'he'): -0.3218439189918105,
#  ('replied', 'that', 'he', 'had'): -1.054603110815242,
#  ('that', 'he', 'had', 'not'): -2.813652228970182,
#  ('he', 'had', 'not', '<END>'): -1.9785079065986653,
#  ('<START>', '<START>', '<START>', 'but'): -3.1264502995101844,
#  ('<START>', '<START>', 'but', 'it'): -2.91433464662886,
#  ('<START>', 'but', 'it', 'is'): -0.8065506789924841,
#  ('but', 'it', 'is', ','): -2.279702167221411,
#  ('it', 'is', ',', 'returned'): -2.635620321272284,
#  ('is', ',', 'returned', 'she'): -0.4957638590746436,
#  (',', 'returned', 'she', ';'): -0.27554763096947155,
#  ('returned', 'she', ';', 'for'): -0.515776490982727,
#  ('she', ';', 'for', 'mrs'): -0.6575069756375151,
#  (';', 'for', 'mrs', '<END>'): -1.2597133161835022e-05,
#  ('<START>', '<START>', '<START>', 'long'): -6.516131299369131,
#  ('<START>', '<START>', 'long', 'has'): -1.7159048440789542,
#  ('<START>', 'long', 'has', 'just'): -1.093362565437037,
#  ('long', 'has', 'just', 'been'): -0.2661465160590795,
#  ('has', 'just', 'been', 'here'): -0.5707490370989328,
#  ('just', 'been', 'here', ','): -0.36861600879687345,
#  ('been', 'here', ',', 'and'): -0.5157204816123699,
#  ('here', ',', 'and', 'she'): -1.6693638312862034,
#  (',', 'and', 'she', 'told'): -3.9540563676400162,
#  ('and', 'she', 'told', 'me'): -0.21677108193733574,
#  ('she', 'told', 'me', 'all'): -1.5590088688084656,
#  ('told', 'me', 'all', 'about'): -0.467632388707448,
#  ('me', 'all', 'about', 'it'): -0.233078764428663,
#  ('all', 'about', 'it', '<END>'): -0.4603586941369912,
#  ('<START>', '<START>', 'bennet', 'made'): -4.487452311272981,
#  ('<START>', 'bennet', 'made', 'no'): -0.0992333117515819,
#  ('bennet', 'made', 'no', 'answer'): -0.13139477712733516,
#  ('made', 'no', 'answer', '<END>'): -0.6326306628496078,
#  ('<START>', '<START>', '<START>', 'do'): -5.535201474407865,
#  ('<START>', '<START>', 'do', 'not'): -0.7853927958001632,
#  ('<START>', 'do', 'not', 'you'): -2.6878785701856054,
#  ('do', 'not', 'you', 'want'): -1.9363123208169253,
#  ('not', 'you', 'want', 'to'): -0.08050232322527653,
#  ('you', 'want', 'to', 'know'): -1.5135829141433403,
#  ('want', 'to', 'know', 'who'): -1.3437174986288174,
#  ('to', 'know', 'who', 'has'): -0.5231894489262823,
#  ('know', 'who', 'has', 'taken'): -0.6354458839997773,
#  ('who', 'has', 'taken', 'it'): -0.42581271476566857,
#  ('has', 'taken', 'it', '<END>'): -0.21634251576211014,
#  ('<START>', '<START>', '<START>', 'cried'): -5.669165066515034,
#  ('<START>', '<START>', 'cried', 'his'): -3.0002100118586092,
#  ('<START>', 'cried', 'his', 'wife'): -0.28396483045010995,
#  ('cried', 'his', 'wife', 'impatiently'): -1.695660384750145,
#  ('his', 'wife', 'impatiently', '<END>'): -0.0811092538352942,
#  ('<START>', '<START>', '<START>', 'you'): -3.5895491303137126,
#  ('<START>', '<START>', 'you', 'want'): -5.157456710032828,
#  ('<START>', 'you', 'want', 'to'): -0.08050232322527653,
#  ('you', 'want', 'to', 'tell'): -1.6464766579149048,
#  ('want', 'to', 'tell', 'me'): -0.5473182121926148,
#  ('to', 'tell', 'me', ','): -0.8821150439941221,
#  ('tell', 'me', ',', 'and'): -1.4734096630496507,
#  ('me', ',', 'and', 'i'): -1.7340286613157734,
#  (',', 'and', 'i', 'have'): -2.499694141435857,
#  ('and', 'i', 'have', 'no'): -1.9214335379249954,
#  ('i', 'have', 'no', 'objection'): -2.438278507101217,
#  ('have', 'no', 'objection', 'to'): -0.8007496069178849,
#  ('no', 'objection', 'to', 'hearing'): -1.2033511617563066,
#  ('objection', 'to', 'hearing', 'it'): -0.22417273112821712,
#  ('to', 'hearing', 'it', '<END>'): -0.48133256463960855,
#  ('<START>', '<START>', '<START>', 'this'): -4.706157459676463,
#  ('<START>', '<START>', 'this', 'was'): -1.4275175272699019,
#  ('<START>', 'this', 'was', 'invitation'): -2.946256527031489,
#  ('this', 'was', 'invitation', 'enough'): -0.27867737988063795,
#  ('was', 'invitation', 'enough', '<END>'): -0.21336442700411234,
#  ('<START>', '<START>', '<START>', 'why'): -5.823363288634698,
#  ('<START>', '<START>', 'why', ','): -0.8904517390200232,
#  ('<START>', 'why', ',', 'my'): -2.234399790074249,
#  ('why', ',', 'my', 'dear'): -0.2543575868345875,
#  (',', 'my', 'dear', ','): -1.2053717145378442,
#  ('my', 'dear', ',', 'you'): -1.9057721594226775,
#  ('dear', ',', 'you', 'must'): -1.0332414248727229,
#  (',', 'you', 'must', 'know'): -2.2817479529036437,
#  ('you', 'must', 'know', ','): -1.1561663432168132,
#  ('must', 'know', ',', 'mrs'): -1.3309057477080586,
#  ('know', ',', 'mrs', '<END>'): -7.558260854508945e-06,
#  ('<START>', '<START>', 'long', 'says'): -2.4284235608934446,
#  ('<START>', 'long', 'says', 'that'): -0.19355760001558467,
#  ('long', 'says', 'that', 'netherfield'): -0.5741134335525492,
#  ('says', 'that', 'netherfield', 'is'): -0.44674089894150726,
#  ('that', 'netherfield', 'is', 'taken'): -0.46920200440038934,
#  ('netherfield', 'is', 'taken', 'by'): -0.2677340149812313,
#  ('is', 'taken', 'by', 'a'): -0.2534847069452921,
#  ('taken', 'by', 'a', 'young'): -0.6308354620595874,
#  ('by', 'a', 'young', 'man'): -0.11825145570500721,
#  ('a', 'young', 'man', 'of'): -1.2060792355196523,
#  ('young', 'man', 'of', 'large'): -2.1149577000177606,
#  ('man', 'of', 'large', 'fortune'): -0.1024951633499623,
#  ('of', 'large', 'fortune', 'from'): -1.1099238734556558,
#  ('large', 'fortune', 'from', 'the'): -0.19461630545595454,
#  ('fortune', 'from', 'the', 'north'): -0.6859702890743854,
#  ('from', 'the', 'north', 'of'): -0.35532545833200807,
#  ('the', 'north', 'of', 'england'): -0.11766938781564756,
#  ('north', 'of', 'england', ';'): -0.17210378122601633,
#  ('of', 'england', ';', 'that'): -0.9600893159587494,
#  ('england', ';', 'that', 'he'): -0.519811895525827,
#  (';', 'that', 'he', 'came'): -2.030711360198775,
#  ('that', 'he', 'came', 'down'): -1.2889428583192768,
#  ('he', 'came', 'down', 'on'): -0.4481343732359588,
#  ('came', 'down', 'on', 'monday'): -0.5377622022553831,
#  ('down', 'on', 'monday', 'in'): -0.39781114797144856,
#  ('on', 'monday', 'in', 'a'): -0.2525254536332026,
#  ('monday', 'in', 'a', 'chaise'): -0.6873866003007625,
#  ('in', 'a', 'chaise', 'and'): -0.2598125952231983,
#  ('a', 'chaise', 'and', 'four'): -0.11761929822355856,
#  ('chaise', 'and', 'four', 'to'): -0.8069769486310902,
#  ('and', 'four', 'to', 'see'): -0.281914818475792,
#  ('four', 'to', 'see', 'the'): -0.5936724938148421,
#  ('to', 'see', 'the', 'place'): -0.5862763358153944,
#  ('see', 'the', 'place', ','): -0.5381096089174571,
#  ('the', 'place', ',', 'and'): -0.9713420229697646,
#  ('place', ',', 'and', 'was'): -1.9445525026968704,
#  (',', 'and', 'was', 'so'): -2.581016248777149,
#  ('and', 'was', 'so', 'much'): -1.087300453885043,
#  ('was', 'so', 'much', 'delighted'): -2.0302508092337797,
#  ('so', 'much', 'delighted', 'with'): -0.1858840532197523,
#  ('much', 'delighted', 'with', 'it'): -0.5341349813412346,
#  ('delighted', 'with', 'it', 'that'): -1.24182548089986,
#  ('with', 'it', 'that', 'he'): -0.37492218980433506,
#  ('it', 'that', 'he', 'agreed'): -1.3759476510048068,
#  ('that', 'he', 'agreed', 'with'): -0.2519239305864771,
#  ('he', 'agreed', 'with', 'mr'): -0.2784904954539622,
#  ('agreed', 'with', 'mr', '<END>'): -3.876024071261365e-06,
#  ('<START>', '<START>', '<START>', 'morris'): -8.713804705599353,
#  ('<START>', '<START>', 'morris', 'immediately'): -0.13232417193238052,
#  ('<START>', 'morris', 'immediately', ';'): -0.24285510784390624,
#  ('morris', 'immediately', ';', 'that'): -0.5752911574523017,
#  ('immediately', ';', 'that', 'he'): -0.519811895525827,
#  (';', 'that', 'he', 'is'): -1.8660174711934563,
#  ('that', 'he', 'is', 'to'): -2.3002498693436233,
#  ('he', 'is', 'to', 'take'): -1.702484971529774,
#  ('is', 'to', 'take', 'possession'): -0.6567281177403137,
#  ('to', 'take', 'possession', 'before'): -0.43608538731613117,
#  ('take', 'possession', 'before', 'michaelmas'): -0.2862610715012751,
#  ('possession', 'before', 'michaelmas', ','): -0.02071401887534402,
#  ('before', 'michaelmas', ',', 'and'): -0.22195692270170286,
#  ('michaelmas', ',', 'and', 'some'): -0.6897218133996429,
#  (',', 'and', 'some', 'of'): -1.2184330312643739,
#  ('and', 'some', 'of', 'his'): -0.5639715229483075,
#  ('some', 'of', 'his', 'servants'): -1.7815685678657862,
#  ('of', 'his', 'servants', 'are'): -0.26510049859756857,
#  ('his', 'servants', 'are', 'to'): -0.22079107778823628,
#  ('servants', 'are', 'to', 'be'): -0.47303618241662954,
#  ('are', 'to', 'be', 'in'): -1.8583685412343633,
#  ('to', 'be', 'in', 'the'): -1.8806966808655876,
#  ('be', 'in', 'the', 'house'): -1.7553853676550375,
#  ('in', 'the', 'house', 'by'): -1.997424134377919,
#  ('the', 'house', 'by', 'the'): -0.1960990445460393,
#  ('house', 'by', 'the', 'end'): -0.68106627130853,
#  ('by', 'the', 'end', 'of'): -0.01670852838116891,
#  ('the', 'end', 'of', 'next'): -2.4634585358453296,
#  ('end', 'of', 'next', 'week'): -0.4563812604016709,
#  ('of', 'next', 'week', '<END>'): -0.25168988097411904,
#  ('<START>', '<START>', '<START>', 'what'): -4.635998097568996,
#  ('<START>', '<START>', 'what', 'is'): -2.040493884397996,
#  ('<START>', 'what', 'is', 'his'): -2.4722652285816538,
#  ('what', 'is', 'his', 'name'): -0.5733441065686665,
#  ('is', 'his', 'name', '<END>'): -0.3355069506919505,
#  ('<START>', '<START>', '<START>', 'is'): -5.667671399999444,
#  ('<START>', '<START>', 'is', 'he'): -3.0433302695679005,
#  ('<START>', 'is', 'he', 'married'): -0.5744246948735234,
#  ('is', 'he', 'married', 'or'): -0.27301402501732275,
#  ('he', 'married', 'or', 'single'): -0.1813918081050893,
#  ('married', 'or', 'single', '<END>'): -0.6941999422560827,
#  ('<START>', '<START>', '<START>', 'single'): -8.713293985077865,
#  ('<START>', '<START>', 'single', ','): -0.08670063204864634,
#  ('<START>', 'single', ',', 'my'): -0.46302357390840726,
#  ('single', ',', 'my', 'dear'): -0.2543575868345875,
#  ('my', 'dear', ',', 'to'): -2.518039656169098,
#  ('dear', ',', 'to', 'be'): -1.1675481099114609,
#  (',', 'to', 'be', 'sure'): -2.3203735123563454,
#  ('to', 'be', 'sure', '<END>'): -1.8726230927312966,
#  ('<START>', '<START>', '<START>', 'a'): -4.974269237594902,
#  ('<START>', '<START>', 'a', 'single'): -3.915659552444305,
#  ('<START>', 'a', 'single', 'man'): -0.48702779960706183,
#  ('a', 'single', 'man', 'of'): -0.8608783169460972,
#  ('single', 'man', 'of', 'large'): -0.621189265483471,
#  ('of', 'large', 'fortune', ';'): -1.07333003848581,
#  ('large', 'fortune', ';', 'four'): -0.4695990032587851,
#  ('fortune', ';', 'four', 'or'): -0.2636485923734983,
#  (';', 'four', 'or', 'five'): -0.18120369891872043,
#  ('four', 'or', 'five', 'thousand'): -0.10926758006470799,
#  ('or', 'five', 'thousand', 'a'): -0.18288254598202655,
#  ('five', 'thousand', 'a', 'year'): -0.6380543857706732,
#  ('thousand', 'a', 'year', '<END>'): -0.9861431854809481,
#  ('<START>', '<START>', 'what', 'a'): -1.9235930224310203,
#  ('<START>', 'what', 'a', 'fine'): -2.62106377769993,
#  ('what', 'a', 'fine', 'thing'): -0.599367827071644,
#  ('a', 'fine', 'thing', 'for'): -0.2653677678767,
#  ('fine', 'thing', 'for', 'our'): -0.5953316243284613,
#  ('thing', 'for', 'our', 'girls'): -0.5707942370324629,
#  ('for', 'our', 'girls', '<END>'): -0.1786432507843106,
#  ('<START>', '<START>', '<START>', 'how'): -4.653247200530122,
#  ('<START>', '<START>', 'how', 'so'): -3.959666714047676,
#  ('<START>', 'how', 'so', '<END>'): -0.18405879899590333,
#  ('<START>', '<START>', 'how', 'can'): -2.3575089288745423,
#  ('<START>', 'how', 'can', 'it'): -1.9588481407322784,
#  ('how', 'can', 'it', 'affect'): -0.5875701944588461,
#  ('can', 'it', 'affect', 'them'): -0.22413784997501046,
#  ('it', 'affect', 'them', '<END>'): -0.18258221859066429,
#  ('<START>', '<START>', 'you', 'must'): -2.325714603119039,
#  ('<START>', 'you', 'must', 'know'): -2.715440859623796,
#  ('you', 'must', 'know', 'that'): -1.160408353377134,
#  ('must', 'know', 'that', 'i'): -1.4928791613376458,
#  ('know', 'that', 'i', 'am'): -0.7698195670533866,
#  ('that', 'i', 'am', 'thinking'): -3.304083212198781,
#  ('i', 'am', 'thinking', 'of'): -0.07440973562663901,
#  ('am', 'thinking', 'of', 'his'): -1.1266062382471504,
#  ('thinking', 'of', 'his', 'marrying'): -0.6861250310446729,
#  ('of', 'his', 'marrying', 'one'): -1.0254019653277748,
#  ('his', 'marrying', 'one', 'of'): -0.18911642014155072,
#  ('marrying', 'one', 'of', 'them'): -0.6077292386952663,
#  ('one', 'of', 'them', '<END>'): -0.9010221766078711,
#  ('<START>', '<START>', 'is', 'that'): -3.0167671845188733,
#  ('<START>', 'is', 'that', 'his'): -0.5920544659325216,
#  ('is', 'that', 'his', 'design'): -0.6751021748611864,
#  ('that', 'his', 'design', 'in'): -0.4213289486944729,
#  ('his', 'design', 'in', 'settling'): -0.2874883766692199,
#  ('design', 'in', 'settling', 'here'): -0.232154862165758,
#  ('in', 'settling', 'here', '<END>'): -0.14751979479047772,
#  ('<START>', '<START>', '<START>', 'nonsense'): -8.713526098434977,
#  ('<START>', '<START>', 'nonsense', ','): -0.05108339467686124,
#  ('<START>', 'nonsense', ',', 'how'): -0.5730633479632861,
#  ('nonsense', ',', 'how', 'can'): -0.5786590604900509,
#  (',', 'how', 'can', 'you'): -0.3740546752134197,
#  ('how', 'can', 'you', 'talk'): -1.6934243256599797,
#  ('can', 'you', 'talk', 'so'): -0.2107394147548005,
#  ('you', 'talk', 'so', '<END>'): -0.07765557589763579,
#  ('but', 'it', 'is', 'very'): -2.7880217868917114,
#  ('it', 'is', 'very', 'likely'): -2.8898479192243594,
#  ('is', 'very', 'likely', 'that'): -0.581315835002992,
#  ('very', 'likely', 'that', 'he'): -0.42157293771346,
#  ('likely', 'that', 'he', 'may'): -0.6757503083348518,
#  ('that', 'he', 'may', 'fall'): -1.6247066714359617,
#  ('he', 'may', 'fall', 'in'): -0.1742693470077286,
#  ('may', 'fall', 'in', 'love'): -0.131300270724172,
#  ('fall', 'in', 'love', 'with'): -1.0600009084372148,
#  ('in', 'love', 'with', 'one'): -2.630579577362047,
#  ('love', 'with', 'one', 'of'): -0.16093774418216913,
#  ('with', 'one', 'of', 'them'): -1.892177604553336,
#  ('one', 'of', 'them', ','): -1.615601316036496,
#  ('of', 'them', ',', 'and'): -1.3536525202522343,
#  ('them', ',', 'and', 'therefore'): -3.3392934598504747,
#  (',', 'and', 'therefore', 'you'): -2.0468251475069987,
#  ('and', 'therefore', 'you', 'must'): -0.4508284330568446,
#  ('therefore', 'you', 'must', 'visit'): -0.6806842641122629,
#  ('you', 'must', 'visit', 'him'): -0.2636361899828364,
#  ('must', 'visit', 'him', 'as'): -0.4995739632889385,
#  ('visit', 'him', 'as', 'soon'): -0.519418993003354,
#  ('him', 'as', 'soon', 'as'): -0.05690649161079692,
#  ('as', 'soon', 'as', 'he'): -1.7196904854052195,
#  ('soon', 'as', 'he', 'comes'): -2.6303190643652905,
#  ('as', 'he', 'comes', '<END>'): -0.43175842654572066,
#  ('<START>', '<START>', '<START>', 'i'): -2.5111495206963195,
#  ('<START>', '<START>', 'i', 'see'): -4.601953689586631,
#  ('<START>', 'i', 'see', 'no'): -1.7780538018065648,
#  ('i', 'see', 'no', 'occasion'): -0.11595395595441749,
#  ('see', 'no', 'occasion', 'for'): -0.08795372232275091,
#  ('no', 'occasion', 'for', 'that'): -2.185204860916494,
#  ('occasion', 'for', 'that', '<END>'): -0.521063388338726,
#  ('<START>', '<START>', '<START>', 'bingley'): -4.181142793699976,
#  ('<START>', '<START>', 'bingley', 'might'): -4.538752335235418,
#  ('<START>', 'bingley', 'might', 'like'): -0.28530551477004984,
#  ('bingley', 'might', 'like', 'you'): -0.259298253515357,
#  ('might', 'like', 'you', 'the'): -0.4258605662416088,
#  ('like', 'you', 'the', 'best'): -0.6213445281139461,
#  ('you', 'the', 'best', 'of'): -0.48795621108535475,
#  ('the', 'best', 'of', 'the'): -0.902218568775746,
#  ('best', 'of', 'the', 'party'): -1.3676758402148277,
#  ('of', 'the', 'party', '<END>'): -0.6994545046336841,
#  ('<START>', 'my', 'dear', ','): -1.4929576819007175,
#  ('dear', ',', 'you', 'flatter'): -1.9271505792984438,
#  (',', 'you', 'flatter', 'me'): -0.2561931725800758,
#  ('you', 'flatter', 'me', '<END>'): -0.18066745990749616,
#  ('<START>', '<START>', 'i', 'certainly'): -5.107742917999318,
#  ('<START>', 'i', 'certainly', 'have'): -0.7618063388310606,
#  ('i', 'certainly', 'have', 'had'): -1.0624412375345378,
#  ('certainly', 'have', 'had', 'my'): -0.6292437544747794,
#  ('have', 'had', 'my', 'share'): -0.5372145590076766,
#  ('had', 'my', 'share', 'of'): -0.2016672368153144,
#  ('my', 'share', 'of', 'beauty'): -1.2602384045299433,
#  ('share', 'of', 'beauty', ','): -0.0609306762333485,
#  ('of', 'beauty', ',', 'but'): -1.051855093965203,
#  ('beauty', ',', 'but', 'i'): -1.1811865723888944,
#  (',', 'but', 'i', 'do'): -3.1565466137112366,
#  ('but', 'i', 'do', 'not'): -0.07733307916062451,
#  ('i', 'do', 'not', 'pretend'): -3.100539734639524,
#  ('do', 'not', 'pretend', 'to'): -0.0033072037604882274,
#  ('not', 'pretend', 'to', 'be'): -0.9956270297632098,
#  ('pretend', 'to', 'be', 'any'): -2.0432002825597415,
#  ('to', 'be', 'any', 'thing'): -0.5155183795440972,
#  ('be', 'any', 'thing', 'extraordinary'): -0.6588735039969174,
#  ('any', 'thing', 'extraordinary', 'now'): -1.335428235664506,
#  ('thing', 'extraordinary', 'now', '<END>'): -0.15992807930119668,
#  ('<START>', '<START>', '<START>', 'when'): -4.602742049951058,
#  ('<START>', '<START>', 'when', 'a'): -3.8183688823485014,
#  ('<START>', 'when', 'a', 'woman'): -0.5712849793662209,
#  ('when', 'a', 'woman', 'has'): -0.6130246142288637,
#  ('a', 'woman', 'has', 'five'): -0.9774345956345157,
#  ('woman', 'has', 'five', 'grown'): -0.28022219807399007,
#  ('has', 'five', 'grown', 'up'): -0.19454843087635515,
#  ('five', 'grown', 'up', 'daughters'): -0.466367959973226,
#  ('grown', 'up', 'daughters', ','): -0.09298763052135778,
#  ('up', 'daughters', ',', 'she'): -0.6236011225784316,
#  ('daughters', ',', 'she', 'ought'): -0.6902981751203691,
#  (',', 'she', 'ought', 'to'): -0.1267518891245239,
#  ('she', 'ought', 'to', 'give'): -0.6553439696676508,
#  ('ought', 'to', 'give', 'over'): -0.6729476429092128,
#  ('to', 'give', 'over', 'thinking'): -0.46628240791237635,
#  ('give', 'over', 'thinking', 'of'): -0.17595545633267864,
#  ('over', 'thinking', 'of', 'her'): -0.4528854979589572,
#  ('thinking', 'of', 'her', 'own'): -1.3143517151721742,
#  ('of', 'her', 'own', 'beauty'): -2.8231079157723977,
#  ('her', 'own', 'beauty', '<END>'): -0.13930669077433075,
#  ('<START>', '<START>', '<START>', 'in'): -4.478628611124252,
#  ('<START>', '<START>', 'in', 'such'): -3.5567791425493724,
#  ('<START>', 'in', 'such', 'cases'): -1.2623942349025177,
#  ('in', 'such', 'cases', ','): -0.9372372515483797,
#  ('such', 'cases', ',', 'a'): -0.2778495433956284,
#  ('cases', ',', 'a', 'woman'): -0.6684071893250255,
#  (',', 'a', 'woman', 'has'): -1.2319953774327184,
#  ('a', 'woman', 'has', 'not'): -0.9042276415992667,
#  ('woman', 'has', 'not', 'often'): -0.6549937286931423,
#  ('has', 'not', 'often', 'much'): -0.6293738712157357,
#  ('not', 'often', 'much', 'beauty'): -0.2865637147173506,
#  ('often', 'much', 'beauty', 'to'): -0.2151157404007571,
#  ('much', 'beauty', 'to', 'think'): -0.28225422743236334,
#  ('beauty', 'to', 'think', 'of'): -0.503998903321462,
#  ('to', 'think', 'of', '<END>'): -2.3420015863329935,
#  ('<START>', '<START>', 'but', ','): -2.3638315731692146,
#  ('<START>', 'but', ',', 'my'): -1.5814399684460674,
#  ('but', ',', 'my', 'dear'): -0.2708810208982193,
#  (',', 'you', 'must', 'indeed'): -3.5391443580266095,
#  ('you', 'must', 'indeed', 'go'): -0.2832400127071317,
#  ('must', 'indeed', 'go', 'and'): -0.23552388562906107,
#  ('indeed', 'go', 'and', 'see'): -0.18104104361910073,
#  ('go', 'and', 'see', 'mr'): -1.2092367243004476,
#  ('and', 'see', 'mr', '<END>'): -9.69008834747887e-06,
#  ('<START>', '<START>', 'bingley', 'when'): -4.501754806427199,
#  ('<START>', 'bingley', 'when', 'he'): -0.2577265267494786,
#  ('bingley', 'when', 'he', 'comes'): -0.6654126404193478,
#  ('when', 'he', 'comes', 'into'): -0.6029927070523368,
#  ('he', 'comes', 'into', 'the'): -0.14946173204851737,
#  ('comes', 'into', 'the', 'neighbourhood'): -0.6787014496454299,
#  ('into', 'the', 'neighbourhood', '<END>'): -0.4624526379585417,
#  ('<START>', 'it', 'is', 'more'): -4.33290769878526,
#  ('it', 'is', 'more', 'than'): -0.3975408483906786,
#  ('is', 'more', 'than', 'i'): -1.1989210635438194,
#  ('more', 'than', 'i', 'engage'): -2.112254712515796,
#  ('than', 'i', 'engage', 'for'): -0.2228992847234304,
#  ('i', 'engage', 'for', ','): -0.2051655526851133,
#  ('engage', 'for', ',', 'i'): -0.6024750397746365,
#  ('for', ',', 'i', 'assure'): -0.6759014856712102,
#  (',', 'i', 'assure', 'you'): -0.0019809980966076775,
#  ('i', 'assure', 'you', '<END>'): -1.5168054501842227,
#  ('<START>', '<START>', 'but', 'consider'): -5.589296124787963,
#  ('<START>', 'but', 'consider', 'your'): -0.5104208812415318,
#  ('but', 'consider', 'your', 'daughters'): -0.46761296958423687,
#  ('consider', 'your', 'daughters', '<END>'): -0.30208937087554855,
#  ('<START>', '<START>', '<START>', 'only'): -6.633301390006226,
#  ('<START>', '<START>', 'only', 'think'): -0.5804371651117951,
#  ('<START>', 'only', 'think', 'what'): -1.0770952943828647,
#  ('only', 'think', 'what', 'an'): -1.368252018081481,
#  ('think', 'what', 'an', 'establishment'): -0.5725443529103029,
#  ('what', 'an', 'establishment', 'it'): -0.4614147948155614,
#  ('an', 'establishment', 'it', 'would'): -0.2719445008734913,
#  ('establishment', 'it', 'would', 'be'): -0.34086553774997275,
#  ('it', 'would', 'be', 'for'): -2.8836112925968647,
#  ('would', 'be', 'for', 'one'): -1.2892968224432846,
#  ('be', 'for', 'one', 'of'): -0.22090427596206516,
#  ('for', 'one', 'of', 'them'): -1.554699958221805,
#  ('<START>', '<START>', '<START>', 'sir'): -6.410945648257661,
#  ('<START>', '<START>', 'sir', 'william'): -0.11922805387874852,
#  ('<START>', 'sir', 'william', 'and'): -1.6420792160290683,
#  ('sir', 'william', 'and', 'lady'): -0.8925381826871635,
#  ('william', 'and', 'lady', 'lucas'): -0.28937625593339383,
#  ('and', 'lady', 'lucas', 'are'): -1.6600935858570396,
#  ('lady', 'lucas', 'are', 'determined'): -0.2851118704149638,
#  ('lucas', 'are', 'determined', 'to'): -0.07236689200768066,
#  ('are', 'determined', 'to', 'go'): -1.4638816503347631,
#  ('determined', 'to', 'go', ','): -1.029606748719548,
#  ('to', 'go', ',', 'merely'): -1.528664430691391,
#  ('go', ',', 'merely', 'on'): -0.4454568764428576,
#  (',', 'merely', 'on', 'that'): -0.2674637299992933,
#  ('merely', 'on', 'that', 'account'): -0.6562987679129427,
#  ('on', 'that', 'account', ','): -0.152569156153871,
#  ('that', 'account', ',', 'for'): -0.5633371816156504,
#  ('account', ',', 'for', 'in'): -0.6609798612303647,
#  (',', 'for', 'in', 'general'): -1.517714490526637,
#  ('for', 'in', 'general', 'you'): -0.619762561675027,
#  ('in', 'general', 'you', 'know'): -0.27704266914125103,
#  ('general', 'you', 'know', 'they'): -0.6683740307315316,
#  ('you', 'know', 'they', 'visit'): -0.46873224984059686,
#  ('know', 'they', 'visit', 'no'): -0.27611605430003433,
#  ('they', 'visit', 'no', 'new'): -0.2867750430681875,
#  ('visit', 'no', 'new', 'comers'): -0.27936085510402897,
#  ('no', 'new', 'comers', '<END>'): -0.007586940475583478,
#  ('<START>', '<START>', '<START>', 'indeed'): -6.315635046378197,
#  ('<START>', '<START>', 'indeed', 'you'): -2.4166418686645192,
#  ('<START>', 'indeed', 'you', 'must'): -0.4508284330568446,
#  ('indeed', 'you', 'must', 'go'): -0.6648290828099966,
#  ('you', 'must', 'go', ','): -0.9192558354467864,
#  ('must', 'go', ',', 'for'): -0.5855383714531495,
#  ('go', ',', 'for', 'it'): -0.642508234831794,
#  (',', 'for', 'it', 'will'): -2.305849878905725,
#  ('for', 'it', 'will', 'be'): -0.33876581932618954,
#  ('it', 'will', 'be', 'impossible'): -2.5974707296213735,
#  ('will', 'be', 'impossible', 'for'): -0.223090372553794,
#  ('be', 'impossible', 'for', 'us'): -1.1678228375453947,
#  ('impossible', 'for', 'us', 'to'): -0.23314044482162988,
#  ('for', 'us', 'to', 'visit'): -1.8517357547480056,
#  ('us', 'to', 'visit', 'him'): -0.5212598919707797,
#  ('to', 'visit', 'him', ','): -0.1630585342382233,
#  ('visit', 'him', ',', 'if'): -1.350801771969624,
#  ('him', ',', 'if', 'you'): -1.019291103119524,
#  (',', 'if', 'you', 'do'): -2.398809239561189,
#  ('if', 'you', 'do', 'not'): -0.21158253735006968,
#  ('you', 'do', 'not', '<END>'): -2.4909238381423653,
#  ('<START>', '<START>', 'you', 'are'): -1.8653344507835288,
#  ('<START>', 'you', 'are', 'over'): -3.683153150904906,
#  ('you', 'are', 'over', 'scrupulous'): -0.28486882477829695,
#  ('are', 'over', 'scrupulous', 'surely'): -0.13344023076658088,
#  ('over', 'scrupulous', 'surely', '<END>'): -0.10681516458119751,
#  ('<START>', '<START>', 'i', 'dare'): -4.252782716098595,
#  ('<START>', 'i', 'dare', 'say'): -0.013961904097060612,
#  ('i', 'dare', 'say', 'mr'): -2.703811677648165,
#  ('dare', 'say', 'mr', '<END>'): -1.2920138663005325e-05,
#  ('<START>', '<START>', 'i', 'desire'): -6.211073846996456,
#  ('<START>', 'i', 'desire', 'you'): -0.15673727685794964,
#  ('i', 'desire', 'you', 'will'): -0.11108879848563667,
#  ('desire', 'you', 'will', 'do'): -1.3287159245636366,
#  ('you', 'will', 'do', 'no'): -1.2379394110292294,
#  ('will', 'do', 'no', 'such'): -0.45710566103477096,
#  ('do', 'no', 'such', 'thing'): -0.5333830108664179,
#  ('no', 'such', 'thing', '<END>'): -0.0318012615975717,
#  ('<START>', '<START>', '<START>', 'lizzy'): -6.2286271866868335,
#  ('<START>', '<START>', 'lizzy', 'is'): -1.8228484911920613,
#  ('<START>', 'lizzy', 'is', 'not'): -0.9034985085433133,
#  ('lizzy', 'is', 'not', 'a'): -0.6280341937419844,
#  ('is', 'not', 'a', 'bit'): -1.184782145501128,
#  ('not', 'a', 'bit', 'better'): -0.8526300688193751,
#  ('a', 'bit', 'better', 'than'): -0.2642960376705434,
#  ('bit', 'better', 'than', 'the'): -0.5286505635098847,
#  ('better', 'than', 'the', 'others'): -0.6593871321993137,
#  ('than', 'the', 'others', ';'): -0.5714062590148355,
#  ('the', 'others', ';', 'and'): -0.5239389612685975,
#  ('others', ';', 'and', 'i'): -1.2604774027267749,
#  (';', 'and', 'i', 'am'): -1.6462919658090818,
#  ('and', 'i', 'am', 'sure'): -1.3437918663242274,
#  ('i', 'am', 'sure', 'she'): -2.841819203805579,
#  ('am', 'sure', 'she', 'is'): -1.3410863270200137,
#  ('sure', 'she', 'is', 'not'): -0.5957439945559957,
#  ('she', 'is', 'not', 'half'): -2.0417236066961975,
#  ('is', 'not', 'half', 'so'): -0.25669488632790505,
#  ('not', 'half', 'so', 'handsome'): -0.5953803175757264,
#  ('half', 'so', 'handsome', 'as'): -0.3952388717726435,
#  ('so', 'handsome', 'as', 'jane'): -1.1554502616836073,
#  ('handsome', 'as', 'jane', ','): -0.38794746324927176,
#  ('as', 'jane', ',', 'nor'): -0.6822377419501514,
#  ('jane', ',', 'nor', 'half'): -0.6713938977561373,
#  (',', 'nor', 'half', 'so'): -0.25669488632790505,
#  ('nor', 'half', 'so', 'good'): -0.5932328627849032,
#  ('half', 'so', 'good', 'humoured'): -0.5320913289642847,
#  ('so', 'good', 'humoured', 'as'): -0.5094285751229148,
#  ('good', 'humoured', 'as', 'lydia'): -0.2856993054544593,
#  ('humoured', 'as', 'lydia', '<END>'): -0.4349759119253054,
#  ('<START>', '<START>', 'but', 'you'): -3.2616956867778697,
#  ('<START>', 'but', 'you', 'are'): -1.8918400297291345,
#  ('but', 'you', 'are', 'always'): -1.3511386868338235,
#  ('you', 'are', 'always', 'giving'): -1.0898299708322243,
#  ('are', 'always', 'giving', 'her'): -0.3769019338644027,
#  ('always', 'giving', 'her', 'the'): -0.5338175269702058,
#  ('giving', 'her', 'the', 'preference'): -0.6517049242734271,
#  ('her', 'the', 'preference', '<END>'): -0.4262522167053511,
#  ('<START>', '<START>', '<START>', 'they'): -4.031498480032953,
#  ('<START>', '<START>', 'they', 'have'): -2.7692751021069166,
#  ('<START>', 'they', 'have', 'none'): -2.3444728224270377,
#  ('they', 'have', 'none', 'of'): -0.2658631525875436,
#  ('have', 'none', 'of', 'them'): -0.5229293816505046,
#  ('none', 'of', 'them', 'much'): -1.7351481149499954,
#  ('of', 'them', 'much', 'to'): -0.3880914684703378,
#  ('them', 'much', 'to', 'recommend'): -0.6624230861968398,
#  ('much', 'to', 'recommend', 'them'): -0.5143426256710449,
#  ('to', 'recommend', 'them', ','): -0.7436404473357795,
#  ('recommend', 'them', ',', 'replied'): -0.6805819920476315,
#  ('them', ',', 'replied', 'he'): -0.6318929917388877,
#  (',', 'replied', 'he', ';'): -0.5683975280114978,
#  ('replied', 'he', ';', 'they'): -1.089544652290891,
#  ('he', ';', 'they', 'are'): -0.34394297842336813,
#  (';', 'they', 'are', 'all'): -1.809857554109446,
#  ('they', 'are', 'all', 'silly'): -1.649584442238663,
#  ('are', 'all', 'silly', 'and'): -0.20034922866689142,
#  ('all', 'silly', 'and', 'ignorant'): -0.28731982196275613,
#  ('silly', 'and', 'ignorant', 'like'): -0.4500770715196506,
#  ('and', 'ignorant', 'like', 'other'): -0.27827309021075003,
#  ('ignorant', 'like', 'other', 'girls'): -0.46639478344521024,
#  ('like', 'other', 'girls', ';'): -0.43584222391327887,
#  ('other', 'girls', ';', 'but'): -0.22974720255909842,
#  ('girls', ';', 'but', 'lizzy'): -0.6889325305577582,
#  (';', 'but', 'lizzy', 'has'): -0.4640718756870764,
#  ('but', 'lizzy', 'has', 'something'): -0.28539716099783546,
#  ('lizzy', 'has', 'something', 'more'): -0.26105062131806905,
#  ('has', 'something', 'more', 'of'): -0.37037009302549845,
#  ('something', 'more', 'of', 'quickness'): -1.6578441261431265,
#  ('more', 'of', 'quickness', 'than'): -0.22748715533470876,
#  ('of', 'quickness', 'than', 'her'): -0.25308233160936316,
#  ('quickness', 'than', 'her', 'sisters'): -0.5622251620375508,
#  ('than', 'her', 'sisters', '<END>'): -1.0013726920032162,
#  ('<START>', 'bennet', ',', 'how'): -4.149144290140739,
#  ('bennet', ',', 'how', 'can'): -0.5786590604900509,
#  ('how', 'can', 'you', 'abuse'): -2.387764415282651,
#  ('can', 'you', 'abuse', 'your'): -0.19818539738026308,
#  ('you', 'abuse', 'your', 'own'): -0.2767595487710502,
#  ('abuse', 'your', 'own', 'children'): -0.6200594211886289,
#  ('your', 'own', 'children', 'in'): -1.0081940768346358,
#  ('own', 'children', 'in', 'such'): -0.2792581673553992,
#  ('children', 'in', 'such', 'a'): -0.349665966065964,
#  ('in', 'such', 'a', 'way'): -1.9761276910709638,
#  ('such', 'a', 'way', '<END>'): -0.8702645070618032,
#  ('<START>', '<START>', 'you', 'take'): -4.47172601778255,
#  ('<START>', 'you', 'take', 'delight'): -1.1544809965741465,
#  ('you', 'take', 'delight', 'in'): -0.2239763392646481,
#  ('take', 'delight', 'in', 'vexing'): -0.5751305923586832,
#  ('delight', 'in', 'vexing', 'me'): -0.12472716057780167,
#  ('in', 'vexing', 'me', '<END>'): -0.18066745990749616,
#  ('<START>', '<START>', 'you', 'have'): -2.3121672809215137,
#  ('<START>', 'you', 'have', 'no'): -2.428978637618049,
#  ('you', 'have', 'no', 'compassion'): -2.000497152489687,
#  ('have', 'no', 'compassion', 'on'): -0.23912435235400337,
#  ('no', 'compassion', 'on', 'my'): -0.17471342734045966,
#  ('compassion', 'on', 'my', 'poor'): -1.317111228422746,
#  ('on', 'my', 'poor', 'nerves'): -0.47849495373235046,
#  ('my', 'poor', 'nerves', '<END>'): -0.001344589295794208,
#  ('<START>', '<START>', 'you', 'mistake'): -5.18184012140119,
#  ('<START>', 'you', 'mistake', 'me'): -0.25195279408617843,
#  ('you', 'mistake', 'me', ','): -0.14677002315919843,
#  ('mistake', 'me', ',', 'my'): -0.6462520723224603,
#  ('me', ',', 'my', 'dear'): -0.07781219245790491,
#  (',', 'my', 'dear', '<END>'): -2.8280687212766185,
#  ('<START>', '<START>', 'i', 'have'): -2.311641823674461,
#  ('<START>', 'i', 'have', 'a'): -3.1641237852608373,
#  ('i', 'have', 'a', 'high'): -1.9954321653412235,
#  ('have', 'a', 'high', 'respect'): -0.4545990082252891,
#  ('a', 'high', 'respect', 'for'): -0.23658858300352692,
#  ('high', 'respect', 'for', 'your'): -0.563813530528863,
#  ('respect', 'for', 'your', 'nerves'): -0.6632601515744984,
#  ('for', 'your', 'nerves', '<END>'): -0.0030278722986350343,
#  ('<START>', '<START>', 'they', 'are'): -2.410666080651545,
#  ('<START>', 'they', 'are', 'my'): -2.6645225420263685,
#  ('they', 'are', 'my', 'old'): -0.2871204114965562,
#  ('are', 'my', 'old', 'friends'): -0.26912471309577096,
#  ('my', 'old', 'friends', '<END>'): -0.1575042379852991,
#  ('<START>', 'i', 'have', 'heard'): -2.7249241099157775,
#  ('i', 'have', 'heard', 'you'): -0.8125294399229024,
#  ('have', 'heard', 'you', 'mention'): -1.7033056200306074,
#  ('heard', 'you', 'mention', 'them'): -0.2715345603375517,
#  ('you', 'mention', 'them', 'with'): -0.27215733016049254,
#  ('mention', 'them', 'with', 'consideration'): -0.631959633016075,
#  ('them', 'with', 'consideration', 'these'): -0.26969443091947953,
#  ('with', 'consideration', 'these', 'twenty'): -0.28430689443022406,
#  ('consideration', 'these', 'twenty', 'years'): -0.24050477253711572,
#  ('these', 'twenty', 'years', 'at'): -0.5144720118994186,
#  ('twenty', 'years', 'at', 'least'): -0.27390791639084283,
#  ('years', 'at', 'least', '<END>'): -0.48709403566355053,
#  ('<START>', '<START>', 'you', 'do'): -3.533101571595582,
#  ('<START>', 'you', 'do', 'not'): -0.06154546475636322,
#  ('you', 'do', 'not', 'know'): -1.7877080229870015,
#  ('do', 'not', 'know', 'what'): -1.8624888468375542,
#  ('not', 'know', 'what', 'i'): -1.7860722418002266,
#  ('know', 'what', 'i', 'suffer'): -1.3194401282891477,
#  ('what', 'i', 'suffer', '<END>'): -0.1424796682561786,
#  ('<START>', '<START>', 'it', 'will'): -3.7041878006781084,
#  ('<START>', 'it', 'will', 'be'): -0.8885689595267545,
#  ('it', 'will', 'be', 'no'): -3.1854241487412818,
#  ('will', 'be', 'no', 'use'): -0.6179342455925968,
#  ('be', 'no', 'use', 'to'): -0.19187203038760856,
#  ('no', 'use', 'to', 'us'): -0.5367187460586031,
#  ('use', 'to', 'us', ','): -0.3223269384135579,
#  ('to', 'us', ',', 'if'): -1.999565882440636,
#  ('us', ',', 'if', 'twenty'): -1.3672177493198558,
#  (',', 'if', 'twenty', 'such'): -0.2651761272608679,
#  ('if', 'twenty', 'such', 'should'): -0.28378850043350345,
#  ('twenty', 'such', 'should', 'come'): -0.2831411557334331,
#  ('such', 'should', 'come', 'since'): -0.5071762735351714,
#  ('should', 'come', 'since', 'you'): -0.254368226934303,
#  ('come', 'since', 'you', 'will'): -0.34143915758171156,
#  ('since', 'you', 'will', 'not'): -0.30376739011787796,
#  ('you', 'will', 'not', 'visit'): -3.1928683421070483,
#  ('will', 'not', 'visit', 'them'): -0.44625054192684876,
#  ('not', 'visit', 'them', '<END>'): -0.2659298243114904,
#  ('<START>', '<START>', '<START>', 'depend'): -8.71278352525869,
#  ('<START>', '<START>', 'depend', 'upon'): -0.1222694233736922,
#  ('<START>', 'depend', 'upon', 'it'): -0.31044466227549466,
#  ('depend', 'upon', 'it', ','): -0.35377941254110923,
#  ('upon', 'it', ',', 'my'): -2.465471120597955,
#  ('it', ',', 'my', 'dear'): -0.1621939043181667,
#  ('my', 'dear', ',', 'that'): -3.1571813234149246,
#  ('dear', ',', 'that', 'when'): -0.683728080791937,
#  (',', 'that', 'when', 'there'): -1.3715724006928447,
#  ('that', 'when', 'there', 'are'): -1.0554529863517408,
#  ('when', 'there', 'are', 'twenty'): -0.6612700397161068,
#  ('there', 'are', 'twenty', ','): -0.1041979808638761,
#  ('are', 'twenty', ',', 'i'): -0.1694408819787703,
#  ('twenty', ',', 'i', 'will'): -1.3369607487328456,
#  (',', 'i', 'will', 'visit'): -2.6270731614875404,
#  ('i', 'will', 'visit', 'them'): -0.9415485435127499,
#  ('will', 'visit', 'them', 'all'): -0.49402046363624413,
#  ('visit', 'them', 'all', '<END>'): -0.46249615907242403,
#  ('<START>', '<START>', 'bennet', 'was'): -1.913336564884335,
#  ('<START>', 'bennet', 'was', 'so'): -3.3213527252052923,
#  ('bennet', 'was', 'so', 'odd'): -0.6726396198996947,
#  ('was', 'so', 'odd', 'a'): -0.2126206883189894,
#  ('so', 'odd', 'a', 'mixture'): -0.28690680075794156,
#  ('odd', 'a', 'mixture', 'of'): -0.006792409307582563,
#  ('a', 'mixture', 'of', 'quick'): -1.828832564505634,
#  ('mixture', 'of', 'quick', 'parts'): -0.26926331852389135,
#  ('of', 'quick', 'parts', ','): -0.04221284732490505,
#  ('quick', 'parts', ',', 'sarcastic'): -0.28764110657855135,
#  ('parts', ',', 'sarcastic', 'humour'): -0.13305288555741318,
#  (',', 'sarcastic', 'humour', ','): -0.07035818537130302,
#  ('sarcastic', 'humour', ',', 'reserve'): -0.6189656420284904,
#  ('humour', ',', 'reserve', ','): -0.0251132897671395,
#  (',', 'reserve', ',', 'and'): -0.42098510075634454,
#  ('reserve', ',', 'and', 'caprice'): -1.3849754174797337,
#  (',', 'and', 'caprice', ','): -0.18192278500576162,
#  ('and', 'caprice', ',', 'that'): -0.26919194956738984,
#  ('caprice', ',', 'that', 'the'): -0.6291041524770666,
#  (',', 'that', 'the', 'experience'): -3.3919374235090283,
#  ('that', 'the', 'experience', 'of'): -0.13173248287046846,
#  ('the', 'experience', 'of', 'three'): -0.2870145434200252,
#  ('experience', 'of', 'three', 'and'): -0.39386433509240576,
#  ('of', 'three', 'and', 'twenty'): -0.2871110328207124,
#  ('three', 'and', 'twenty', 'years'): -0.4274451544027553,
#  ('and', 'twenty', 'years', 'had'): -1.0435802890155548,
#  ('twenty', 'years', 'had', 'been'): -0.23814120380084386,
#  ('years', 'had', 'been', 'insufficient'): -0.6890225993862171,
#  ('had', 'been', 'insufficient', 'to'): -0.1603916406206643,
#  ('been', 'insufficient', 'to', 'make'): -0.46127526003424724,
#  ('insufficient', 'to', 'make', 'his'): -0.6393095675001541,
#  ('to', 'make', 'his', 'wife'): -1.6518774673452479,
#  ('make', 'his', 'wife', 'understand'): -0.6596158401990967,
#  ('his', 'wife', 'understand', 'his'): -0.25196530968374214,
#  ('wife', 'understand', 'his', 'character'): -0.179803243398112,
#  ('understand', 'his', 'character', '<END>'): -0.289129741772434,
#  ('<START>', '<START>', '<START>', 'her'): -4.4086030816579544,
#  ('<START>', '<START>', 'her', 'mind'): -3.7639535633570382,
#  ('<START>', 'her', 'mind', 'was'): -1.0782833570854446,
#  ('her', 'mind', 'was', 'less'): -1.2483239610380579,
#  ('mind', 'was', 'less', 'difficult'): -0.5936571844760189,
#  ('was', 'less', 'difficult', 'to'): -0.1507930922755626,
#  ('less', 'difficult', 'to', 'develope'): -0.538885734399435,
#  ('difficult', 'to', 'develope', '<END>'): -0.007586940475583478,
#  ('<START>', '<START>', '<START>', 'she'): -3.145252302500875,
#  ('<START>', '<START>', 'she', 'was'): -1.8172601669887296,
#  ('<START>', 'she', 'was', 'a'): -2.973329359864703,
#  ('she', 'was', 'a', 'woman'): -2.151317129613902,
#  ('was', 'a', 'woman', 'of'): -0.5749100910758173,
#  ('a', 'woman', 'of', 'mean'): -0.5748553119697272,
#  ('woman', 'of', 'mean', 'understanding'): -0.2801519736288318,
#  ('of', 'mean', 'understanding', ','): -0.08672134537415077,
#  ('mean', 'understanding', ',', 'little'): -0.5742460958974029,
#  ('understanding', ',', 'little', 'information'): -0.4677774506342177,
#  (',', 'little', 'information', ','): -0.11189761602347408,
#  ('little', 'information', ',', 'and'): -0.4859706090123346,
#  ('information', ',', 'and', 'uncertain'): -1.3851181529765118,
#  (',', 'and', 'uncertain', 'temper'): -0.20712405895738203,
#  ('and', 'uncertain', 'temper', '<END>'): -0.1437647604792339,
#  ('<START>', '<START>', 'when', 'she'): -2.131357963711281,
#  ('<START>', 'when', 'she', 'was'): -1.5396735735349625,
#  ('when', 'she', 'was', 'discontented'): -2.182114182018902,
#  ('she', 'was', 'discontented', 'she'): -0.17302381740773035,
#  ('was', 'discontented', 'she', 'fancied'): -0.2872510854903741,
#  ('discontented', 'she', 'fancied', 'herself'): -0.42469598599331937,
#  ('she', 'fancied', 'herself', 'nervous'): -0.2863466842664924,
#  ('fancied', 'herself', 'nervous', '<END>'): -0.12061104040410717,
#  ('<START>', '<START>', '<START>', 'the'): -3.2620449825659468,
#  ('<START>', '<START>', 'the', 'business'): -4.861352348072588,
#  ('<START>', 'the', 'business', 'of'): -0.9875870862020911,
#  ('the', 'business', 'of', 'her'): -0.6760290492731671,
#  ('business', 'of', 'her', 'life'): -0.39621311792166436,
#  ('of', 'her', 'life', 'was'): -1.8752168494467325,
#  ('her', 'life', 'was', 'to'): -0.46958883935154994,
#  ('life', 'was', 'to', 'get'): -0.6782503883736881,
#  ('was', 'to', 'get', 'her'): -0.616182961308423,
#  ('to', 'get', 'her', 'daughters'): -0.28535316750497103,
#  ('get', 'her', 'daughters', 'married'): -0.6400707560682871,
#  ('her', 'daughters', 'married', ';'): -0.15310607644104512,
#  ('daughters', 'married', ';', 'its'): -1.1841309009402177,
#  ('married', ';', 'its', 'solace'): -0.46761168512873563,
#  (';', 'its', 'solace', 'was'): -0.09811004343764278,
#  ('its', 'solace', 'was', 'visiting'): -0.28747088628787315,
#  ('solace', 'was', 'visiting', 'and'): -0.17030092330333024,
#  ('was', 'visiting', 'and', 'news'): -0.28727793769113774,
#  ('visiting', 'and', 'news', '<END>'): -0.139596333083391,
#  ('<START>', 'bennet', 'was', 'among'): -3.5436303737320927,
#  ('bennet', 'was', 'among', 'the'): -0.16543836417731866,
#  ('was', 'among', 'the', 'earliest'): -0.5973911850436516,
#  ('among', 'the', 'earliest', 'of'): -0.4283620600113001,
#  ('the', 'earliest', 'of', 'those'): -0.2862220277953767,
#  ('earliest', 'of', 'those', 'who'): -0.5109887788532057,
#  ('of', 'those', 'who', 'waited'): -1.6298049044853438,
#  ('those', 'who', 'waited', 'on'): -0.12246780421680578,
#  ('who', 'waited', 'on', 'mr'): -1.0799553625280611,
#  ('waited', 'on', 'mr', '<END>'): -6.460048465143756e-06,
#  ('<START>', '<START>', '<START>', 'he'): -3.4303746910109494,
#  ('<START>', '<START>', 'he', 'had'): -2.6405537484972816,
#  ('<START>', 'he', 'had', 'always'): -3.1109859540659692,
#  ('he', 'had', 'always', 'intended'): -0.6439847521144622,
#  ('had', 'always', 'intended', 'to'): -0.11714578888255217,
#  ('always', 'intended', 'to', 'visit'): -0.6473295239904169,
#  ('intended', 'to', 'visit', 'him'): -0.5212598919707797,
#  ('visit', 'him', ',', 'though'): -1.3373763806322074,
#  ('him', ',', 'though', 'to'): -1.5909198311115764,
#  (',', 'though', 'to', 'the'): -0.24003656525753186,
#  ('though', 'to', 'the', 'last'): -0.6793646558891774,
#  ('to', 'the', 'last', 'always'): -1.9641631695212693,
#  ('the', 'last', 'always', 'assuring'): -0.2859191091975085,
#  ('last', 'always', 'assuring', 'his'): -0.21899414712292076,
#  ('always', 'assuring', 'his', 'wife'): -0.2821113783489315,
#  ('assuring', 'his', 'wife', 'that'): -0.6326592036464508,
#  ('his', 'wife', 'that', 'he'): -0.24716202626240685,
#  ('wife', 'that', 'he', 'should'): -0.6164391136920839,
#  ('that', 'he', 'should', 'not'): -1.7866739148219934,
#  ('he', 'should', 'not', 'go'): -1.7125722587245982,
#  ('should', 'not', 'go', ';'): -0.5925570813902074,
#  ('not', 'go', ';', 'and'): -0.07063668560647832,
#  ('go', ';', 'and', 'till'): -1.7765654180435693,
#  (';', 'and', 'till', 'the'): -0.657137927507031,
#  ('and', 'till', 'the', 'evening'): -1.2489321459812082,
#  ('till', 'the', 'evening', 'after'): -1.3414510447371257,
#  ('the', 'evening', 'after', 'the'): -0.20516671015206225,
#  ('evening', 'after', 'the', 'visit'): -0.6642420152695203,
#  ('after', 'the', 'visit', 'was'): -0.4109625841040363,
#  ('the', 'visit', 'was', 'paid'): -0.7149416866010269,
#  ('visit', 'was', 'paid', ','): -0.03958855124815051,
#  ('was', 'paid', ',', 'she'): -1.1215223978611966,
#  ('paid', ',', 'she', 'had'): -0.6151918065831741,
#  (',', 'she', 'had', 'no'): -2.223950348235289,
#  ('she', 'had', 'no', 'knowledge'): -2.8994027000230176,
#  ('had', 'no', 'knowledge', 'of'): -0.11011416173095354,
#  ('no', 'knowledge', 'of', 'it'): -0.5445197515895297,
#  ('knowledge', 'of', 'it', '<END>'): -0.8508605821042786,
#  ('<START>', '<START>', 'it', 'was'): -1.0258044123290784,
#  ('<START>', 'it', 'was', 'then'): -4.396672351328127,
#  ('it', 'was', 'then', 'disclosed'): -1.3083042158532434,
#  ('was', 'then', 'disclosed', 'in'): -0.0964176051538284,
#  ('then', 'disclosed', 'in', 'the'): -0.19911458009227626,
#  ('disclosed', 'in', 'the', 'following'): -0.6880941543180774,
#  ('in', 'the', 'following', 'manner'): -0.3536634485052204,
#  ('the', 'following', 'manner', '<END>'): -0.7888757519340655,
#  ('<START>', '<START>', '<START>', 'observing'): -8.713340403439359,
#  ('<START>', '<START>', 'observing', 'his'): -0.22947816443123722,
#  ('<START>', 'observing', 'his', 'second'): -0.4682618061264501,
#  ('observing', 'his', 'second', 'daughter'): -0.3550340724422233,
#  ('his', 'second', 'daughter', 'employed'): -1.3753784551915862,
#  ('second', 'daughter', 'employed', 'in'): -0.14091453879387292,
#  ('daughter', 'employed', 'in', 'trimming'): -0.5387712884109309,
#  ('employed', 'in', 'trimming', 'a'): -0.09483765266260588,
#  ('in', 'trimming', 'a', 'hat'): -0.2875126831170001,
#  ('trimming', 'a', 'hat', ','): -0.02071401887534402,
#  ('a', 'hat', ',', 'he'): -0.2766586358316756,
#  ('hat', ',', 'he', 'suddenly'): -0.6836961486479853,
#  (',', 'he', 'suddenly', 'addressed'): -1.0474676805973386,
#  ('he', 'suddenly', 'addressed', 'her'): -0.4047601150428102,
#  ('suddenly', 'addressed', 'her', 'with'): -0.27366158205241525,
#  ('addressed', 'her', 'with', ','): -0.5634651483745203,
#  ('her', 'with', ',', 'i'): -0.5836263579189012,
#  ('with', ',', 'i', 'hope'): -0.6467401104198754,
#  (',', 'i', 'hope', 'mr'): -3.115926945145666,
#  ('i', 'hope', 'mr', '<END>'): -2.9070546740422627e-05,
#  ('<START>', '<START>', 'bingley', 'will'): -3.4584209212254304,
#  ('<START>', 'bingley', 'will', 'like'): -1.381316010254679,
#  ('bingley', 'will', 'like', 'it'): -0.2517240273777974,
#  ('will', 'like', 'it', 'lizzy'): -0.5742726350799068,
#  ('like', 'it', 'lizzy', '<END>'): -0.18306509461853043,
#  ('<START>', '<START>', '<START>', 'we'): -4.821825193890195,
#  ('<START>', '<START>', 'we', 'are'): -2.2759812715165406,
#  ('<START>', 'we', 'are', 'not'): -0.8431829872983971,
#  ('we', 'are', 'not', 'in'): -1.90048819827269,
#  ('are', 'not', 'in', 'a'): -0.5981635255373257,
#  ('not', 'in', 'a', 'way'): -1.3602880280624916,
#  ('in', 'a', 'way', 'to'): -0.288722860790806,
#  ('a', 'way', 'to', 'know'): -1.3011692248947158,
#  ('way', 'to', 'know', 'what'): -0.550772975818459,
#  ('to', 'know', 'what', 'mr'): -2.130610176541221,
#  ('know', 'what', 'mr', '<END>'): -4.152883508408112e-06,
#  ('<START>', '<START>', 'bingley', 'likes'): -3.8985511038082428,
#  ('<START>', 'bingley', 'likes', ','): -0.6254900231201701,
#  ('bingley', 'likes', ',', 'said'): -0.2791878951859579,
#  ('likes', ',', 'said', 'her'): -0.6159191454604076,
#  (',', 'said', 'her', 'mother'): -1.623687912539765,
#  ('said', 'her', 'mother', 'resentfully'): -2.131651082806245,
#  ('her', 'mother', 'resentfully', ','): -0.02071401887534402,
#  ('mother', 'resentfully', ',', 'since'): -0.28702911482596505,
#  ('resentfully', ',', 'since', 'we'): -0.6226422690180491,
#  (',', 'since', 'we', 'are'): -0.4935607125254465,
#  ('since', 'we', 'are', 'not'): -0.5555009148466162,
#  ('we', 'are', 'not', 'to'): -1.7249183743662329,
#  ('are', 'not', 'to', 'visit'): -1.361228518830933,
#  ('not', 'to', 'visit', '<END>'): -0.4768487931598209,
#  ('<START>', 'but', 'you', 'forget'): -2.6696971100080282,
#  ('but', 'you', 'forget', ','): -0.23324983651846365,
#  ('you', 'forget', ',', 'mama'): -0.4698506212344503,
#  ('forget', ',', 'mama', ','): 0.008364726477753975,
#  (',', 'mama', ',', 'said'): -1.44577080197201,
#  ('mama', ',', 'said', 'elizabeth'): -0.5543275650640865,
#  (',', 'said', 'elizabeth', ','): -0.5326163954526717,
#  ('said', 'elizabeth', ',', 'that'): -2.443555320934602,
#  ('elizabeth', ',', 'that', 'we'): -2.628034488603464,
#  (',', 'that', 'we', 'shall'): -1.589981272906838,
#  ('that', 'we', 'shall', 'meet'): -1.3216161407165672,
#  ('we', 'shall', 'meet', 'him'): -0.25312436382005354,
#  ('shall', 'meet', 'him', 'at'): -0.5224588876608772,
#  ('meet', 'him', 'at', 'the'): -0.5790922479643443,
#  ('him', 'at', 'the', 'assemblies'): -0.6859778676068683,
#  ('at', 'the', 'assemblies', ','): 0.02761454625253443,
#  ('the', 'assemblies', ',', 'and'): -0.14237044402601035,
#  ('assemblies', ',', 'and', 'that'): -1.3208142161238086,
#  (',', 'and', 'that', 'mrs'): -3.7267672386603334,
#  ('and', 'that', 'mrs', '<END>'): -2.1595182577180085e-05,
#  ('<START>', 'long', 'has', 'promised'): -1.0950651713361836,
#  ('long', 'has', 'promised', 'to'): -0.137692112060953,
#  ('has', 'promised', 'to', 'introduce'): -0.6350701875265036,
#  ('promised', 'to', 'introduce', 'him'): -0.49190271824059845,
#  ('to', 'introduce', 'him', '<END>'): -0.800946784960263,
#  ('<START>', '<START>', 'i', 'do'): -2.777407168293685,
#  ('<START>', 'i', 'do', 'not'): -0.20503598002036857,
#  ('i', 'do', 'not', 'believe'): -2.5844137023927893,
#  ('do', 'not', 'believe', 'mrs'): -1.9607956521584415,
#  ('not', 'believe', 'mrs', '<END>'): -7.558517939775298e-05,
#  ('<START>', '<START>', 'long', 'will'): -2.3831555537341047,
#  ('<START>', 'long', 'will', 'do'): -0.2786383492664665,
#  ('long', 'will', 'do', 'any'): -0.6146546359380958,
#  ('will', 'do', 'any', 'such'): -0.5325803835372296,
#  ('do', 'any', 'such', 'thing'): -0.5326835350976334,
#  ('any', 'such', 'thing', '<END>'): -0.06464715496791575,
#  ('<START>', '<START>', 'she', 'has'): -3.526490372957017,
#  ('<START>', 'she', 'has', 'two'): -2.479170011375548,
#  ('she', 'has', 'two', 'nieces'): -0.46763874404776873,
#  ('has', 'two', 'nieces', 'of'): -0.18370676440916975,
#  ('two', 'nieces', 'of', 'her'): -0.426538406136997,
#  ('nieces', 'of', 'her', 'own'): -0.6565290290222664,
#  ('of', 'her', 'own', '<END>'): -1.90784437026436,
#  ('<START>', '<START>', 'she', 'is'): -2.7036034099018362,
#  ('<START>', 'she', 'is', 'a'): -1.3902066638128168,
#  ('she', 'is', 'a', 'selfish'): -2.2647910468575274,
#  ('is', 'a', 'selfish', ','): -0.19568421226360105,
#  ('a', 'selfish', ',', 'hypocritical'): -0.46994893113371833,
#  ('selfish', ',', 'hypocritical', 'woman'): -0.20648642895735994,
#  (',', 'hypocritical', 'woman', ','): -0.11989411429538399,
#  ('hypocritical', 'woman', ',', 'and'): -0.46422499230288644,
#  ('woman', ',', 'and', 'i'): -1.653985953642237,
#  ('i', 'have', 'no', 'opinion'): -2.8189960761415143,
#  ('have', 'no', 'opinion', 'of'): -0.15889374567865794,
#  ('no', 'opinion', 'of', 'her'): -0.574011269945074,
#  ('opinion', 'of', 'her', '<END>'): -1.5098444168780414,
#  ('<START>', '<START>', 'bennet', ';'): -3.6523317037429694,
#  ('<START>', 'bennet', ';', 'and'): -0.41309364202715754,
#  ('bennet', ';', 'and', 'i'): -1.6085118000093594,
#  ('and', 'i', 'am', 'glad'): -2.9916116331923486,
#  ('i', 'am', 'glad', 'to'): -1.6876341536630024,
#  ('am', 'glad', 'to', 'find'): -0.5951303476968557,
#  ('glad', 'to', 'find', 'that'): -0.7143107416974078,
#  ('to', 'find', 'that', 'you'): -2.1321733588725404,
#  ('find', 'that', 'you', 'do'): -0.6753627549881561,
#  ('that', 'you', 'do', 'not'): -0.19731672684252183,
#  ('you', 'do', 'not', 'depend'): -3.1500266160590504,
#  ('do', 'not', 'depend', 'on'): -0.3499073428014756,
#  ('not', 'depend', 'on', 'her'): -0.5881000696086308,
#  ('depend', 'on', 'her', 'serving'): -0.6761470422775776,
#  ('on', 'her', 'serving', 'you'): -0.10603879285980326,
#  ('her', 'serving', 'you', '<END>'): -0.22053190168362866,
#  ('<START>', '<START>', '<START>', 'dont'): -8.020611085121264,
#  ('<START>', '<START>', 'dont', 'keep'): -0.8997071614634002,
#  ('<START>', 'dont', 'keep', 'coughing'): -0.27935953661773044,
#  ('dont', 'keep', 'coughing', 'so'): -0.12174949088387718,
#  ('keep', 'coughing', 'so', ','): -0.1474717400420165,
#  ('coughing', 'so', ',', 'kitty'): -0.663518128255581,
#  ('so', ',', 'kitty', ','): -0.10593485609667407,
#  (',', 'kitty', ',', 'for'): -1.4590037268312497,
#  ('kitty', ',', 'for', 'heavens'): -1.3745085419655643,
#  (',', 'for', 'heavens', 'sake'): -0.10512418725477894,
#  ('for', 'heavens', 'sake', '<END>'): -0.816498097198959,
#  ('<START>', '<START>', '<START>', 'have'): -6.4079416126703945,
#  ('<START>', '<START>', 'have', 'a'): -2.305884914052383,
#  ('<START>', 'have', 'a', 'little'): -0.600947290594122,
#  ('have', 'a', 'little', 'compassion'): -2.027075347827999,
#  ('a', 'little', 'compassion', 'on'): -0.23912435235400337,
#  ('little', 'compassion', 'on', 'my'): -0.17471342734045966,
#  ...}

# %%
def Get_perplexity(n, sentences_tokens, log_probabilities):
    all_perplexity = []
    for sentence in sentences_tokens:
        # print("------SENTENCE------\n", sentence)
        single_perplex = 0
        for i in range(len(sentence) - n + 1):
            if tuple(sentence[i:i+n]) in log_probabilities[4].keys():
                # print("Found earlier : ", tuple(sentence[i:i+n]))
                single_perplex += log_probabilities[4][tuple(sentence[i:i+n])]
                # print("Found probability : ",
                    #   witten_bell_probabilities[4][tuple(sentence[i:i+n])])
            else:
                # print("Not found earlier : ", tuple(sentence[i:i+n]))
                log_probabilities[4].setdefault(
                    tuple(sentence[i:i+n]), (1/len(log_probabilities[4].keys())))
                log_probabilities[4][tuple(sentence[i:i+n])] = math.log(witten_bell_for_one(n, tuple(sentence[i:i+n])))
                single_perplex += log_probabilities[4][tuple(sentence[i:i+n])]
            # print(sentence[i:i+n]," : ", math.exp(single_perplex*-1))

        single_perplex /= (len(sentence) - n + 1)
        single_perplex *= -1
        single_perplex = math.exp(single_perplex)
        all_perplexity.append(single_perplex)
    return all_perplexity

# %%
test_sentence_tokens=convert_to_sentence_tokens(test_pride_prejudice,4)
pp = Get_perplexity(4, test_sentence_tokens, log_probabilities_witten)
print('Perplexity : ', sum(pp)/len(pp))
# Out:
# Perplexity :  149.04806202021925

# %% [markdown]
# # KNESER-NEY
#
# <img src="./images/kneser1.png" alt="Kneser-Ney ">

# %%
empty_dict()
common_data(4, train_pride_prejudice, vocab_pride_prejudice)

# %%
discount = 0.9
kneserney_probabilities = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}

# %%
def kneserney_for_one(n, tuple_n):
    history = tuple_n[:(n-1)]
    if (n == 1):
        n_gram_counts[n].setdefault(tuple_n, 1)
        kneserney_probability = n_gram_counts[n][tuple_n] / len(unique_n_grams[n].keys())
        kneserney_probabilities[n].update({tuple_n: kneserney_probability})
        return kneserney_probability

    if (tuple_n not in n_gram_counts[n].keys()):
        n_gram_counts[n].update({tuple_n: 1})
        
    if (n_gram_counts[n-1][history] == 0 or history not in n_gram_counts[n-1].keys()):
        n_gram_counts[n-1].update({history: 1})
        
    unique_n_grams[n-1].setdefault(history, 1)
        
    kneserney_probability = max(0, (n_gram_counts[n][tuple_n]-discount))/n_gram_counts[n-1][history] + (
        (discount*unique_n_grams[n-1][history])/n_gram_counts[n-1][history])*kneserney_for_one(n-1, tuple_n[1:])
    kneserney_probabilities[n].update({tuple_n: kneserney_probability})

    return kneserney_probability

# %%
def kneserney(n):
    for tuplee in n_gram_counts[n].keys():
        kneserney_for_one(n,tuplee)
        
kneserney(4)

# %%
log_probabilities_kneserney = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}}

for i in range(1, 5):
    for key in kneserney_probabilities[i].keys():
        log_probabilities_kneserney[i].update(
            {key: math.log(kneserney_probabilities[i][key])})

# %%
def Get_perplexity(n, sentences_tokens, log_probabilities):
    all_perplexity = []
    for sentence in sentences_tokens:
        # print("------SENTENCE------\n", sentence)
        single_perplex = 0
        for i in range(len(sentence) - n + 1):
            if tuple(sentence[i:i+n]) in log_probabilities[n].keys():
                single_perplex += log_probabilities[n][tuple(sentence[i:i+n])]
            else:

                log_probabilities[n][tuple(sentence[i:i+n])] = math.log(kneserney_for_one(n, tuple(sentence[i:i+n])))
                single_perplex += log_probabilities[4][tuple(sentence[i:i+n])]

        single_perplex /= (len(sentence) - n + 1)
        single_perplex *= -1
        single_perplex = math.exp(single_perplex)
        all_perplexity.append(single_perplex)
    return all_perplexity

# %%
test_sentence_tokens=convert_to_sentence_tokens(test_pride_prejudice,4)
pp = Get_perplexity(4, test_sentence_tokens, log_probabilities_kneserney)
print('Perplexity : ', sum(pp)/len(pp))
# Out:
# Perplexity :  8.76409478342123
